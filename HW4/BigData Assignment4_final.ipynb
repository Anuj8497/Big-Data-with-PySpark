# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.master("local[*]").getOrCreate()
data = spark.read.csv('Amazon_Responded_Oct05.csv',header = True) # Importing the dataset as a csv

# %%
data.show(5)
# Out:
# +--------------------+--------------------+----------------+-----------+-------------------+---------------------+--------------+-----------------+--------------+--------------------+-------------+-------------+--------------------+------------------+--------------------+--------------+--------------------+--------------+---------+-----------------------+-------------------------+-----------------------+-------------+---------+--------------------+
# |              id_str|    tweet_created_at|user_screen_name|user_id_str|user_statuses_count|user_favourites_count|user_protected|user_listed_count|user_following|    user_description|user_location|user_verified|user_followers_count|user_friends_count|     user_created_at|tweet_language|               text_|favorite_count|favorited|in_reply_to_screen_name|in_reply_to_status_id_str|in_reply_to_user_id_str|retweet_count|retweeted|                text|
# +--------------------+--------------------+----------------+-----------+-------------------+---------------------+--------------+-----------------+--------------+--------------------+-------------+-------------+--------------------+------------------+--------------------+--------------+--------------------+--------------+---------+-----------------------+-------------------------+-----------------------+-------------+---------+--------------------+
# |'793270689780203520'|Tue Nov 01 01:57:...|     SeanEPanjab|  143515471|              51287|                 4079|         False|               74|         False|Content marketer;...|   غریب الوطن|        False|                1503|               850|Thu May 13 17:43:...|            en|@AmazonHelp Can y...|             0|    False|             AmazonHelp|                     null|               85741735|            0|    False|                null|
# |'793281386912354304'|Tue Nov 01 02:39:...|      AmazonHelp|   85741735|            2225450|                11366|         False|              796|         False|We answer Amazon ...|         null|         True|              149569|                53|Wed Oct 28 04:17:...|            en|@SeanEPanjab I'm ...|             0|    False|            SeanEPanjab|     7.932706897802035...|              143515471|            0|    False|                null|
# |'793501578766319616'|Tue Nov 01 17:14:...|     SeanEPanjab|  143515471|              51287|                 4079|         False|               74|         False|Content marketer;...|   غریب الوطن|        False|                1503|               850|Thu May 13 17:43:...|            en|@AmazonHelp It wa...|             0|    False|             AmazonHelp|     7.932813869123543...|               85741735|            0|    False|@AmazonHelp It wa...|
# |'793501657346682880'|Tue Nov 01 17:15:...|     SeanEPanjab|  143515471|              51287|                 4079|         False|               74|         False|Content marketer;...|   غریب الوطن|        False|                1503|               850|Thu May 13 17:43:...|            en|@AmazonHelp I am ...|             0|    False|             AmazonHelp|     7.932813869123543...|               85741735|            0|    False|                null|
# |'793502854459879424'|Tue Nov 01 17:19:...|      AmazonHelp|   85741735|            2225450|                11366|         False|              796|         False|We answer Amazon ...|         null|         True|              149569|                53|Wed Oct 28 04:17:...|            en|@SeanEPanjab Plea...|             0|    False|            SeanEPanjab|     7.935015787663196...|              143515471|            0|    False|@SeanEPanjab Plea...|
# +--------------------+--------------------+----------------+-----------+-------------------+---------------------+--------------+-----------------+--------------+--------------------+-------------+-------------+--------------------+------------------+--------------------+--------------+--------------------+--------------+---------+-----------------------+-------------------------+-----------------------+-------------+---------+--------------------+
# only showing top 5 rows

# %%
data_new = data[['tweet_created_at','user_screen_name','user_id_str']]

# %%
data_new # this is Amazon_responded_oct5
# Out:
# DataFrame[tweet_created_at: string, user_screen_name: string, user_id_str: string]

# %%
data_new.first()
# Out:
# Row(tweet_created_at='Tue Nov 01 01:57:25 +0000 2016', user_screen_name='SeanEPanjab', user_id_str='143515471')

# %%
from pyspark.sql import SQLContext
sqlContext = SQLContext(spark.sparkContext)

# %%
from pyspark.sql.types import StringType
from pyspark.sql.types import StructType
from pyspark.sql.functions import udf

# %%
def strip(s):
    return(str(s)[0:10])

# %%
strip_udf = udf(strip,StringType())

# %%
dat = data_new.withColumn('tweet_created', strip_udf(data_new['tweet_created_at']))

# %%
dat.show(10)
# Out:
# +--------------------+----------------+-----------+-------------+
# |    tweet_created_at|user_screen_name|user_id_str|tweet_created|
# +--------------------+----------------+-----------+-------------+
# |Tue Nov 01 01:57:...|     SeanEPanjab|  143515471|   Tue Nov 01|
# |Tue Nov 01 02:39:...|      AmazonHelp|   85741735|   Tue Nov 01|
# |Tue Nov 01 17:14:...|     SeanEPanjab|  143515471|   Tue Nov 01|
# |Tue Nov 01 17:15:...|     SeanEPanjab|  143515471|   Tue Nov 01|
# |Tue Nov 01 17:19:...|      AmazonHelp|   85741735|   Tue Nov 01|
# |Tue Nov 01 17:25:...|      AmazonHelp|   85741735|   Tue Nov 01|
# |Tue Nov 01 17:55:...|     SeanEPanjab|  143515471|   Tue Nov 01|
# |Tue Nov 01 17:55:...|     SeanEPanjab|  143515471|   Tue Nov 01|
# |Tue Nov 01 18:02:...|      AmazonHelp|   85741735|   Tue Nov 01|
# |Tue Nov 01 03:51:...|   aakashwangnoo|   71457972|   Tue Nov 01|
# +--------------------+----------------+-----------+-------------+
# only showing top 10 rows

# %%
sqlContext.registerDataFrameAsTable(dat, "table1")

# %%
daily_active_users = sqlContext.sql("Select user_id_str,user_screen_name,count(DISTINCT tweet_created) as count from table1 group by user_id_str,user_screen_name HAVING count >=5 order by count DESC")

# %%
daily_active_users.show(15) # this is daily user
# Out:
# +------------------+----------------+-----+
# |       user_id_str|user_screen_name|count|
# +------------------+----------------+-----+
# |             False|               0|  561|
# |              null|            null|  525|
# |          85741735|      AmazonHelp|  279|
# |             False|               1|   51|
# |             False|            null|   47|
# |          54704557| SthrnDixieCwgrl|   27|
# |          15413409|   theonetruebix|   19|
# |              null|           False|   18|
# |                75|           False|   17|
# |         133804026|  RichPierce0079|   16|
# |         362763757| BillyTheBigBone|   16|
# |         441572163|   Gentlemen_Sam|   16|
# |                57|           False|   15|
# |         587376186|    Localboy_Ash|   14|
# |720329744726687744|          saj44a|   14|
# +------------------+----------------+-----+
# only showing top 15 rows

# %%
daily_active_users.collect()
# Out:
# [Row(user_id_str='False', user_screen_name='0', count=561),
#  Row(user_id_str=None, user_screen_name=None, count=525),
#  Row(user_id_str='85741735', user_screen_name='AmazonHelp', count=279),
#  Row(user_id_str='False', user_screen_name='1', count=51),
#  Row(user_id_str='False', user_screen_name=None, count=47),
#  Row(user_id_str='54704557', user_screen_name='SthrnDixieCwgrl', count=27),
#  Row(user_id_str='15413409', user_screen_name='theonetruebix', count=19),
#  Row(user_id_str=None, user_screen_name='False', count=18),
#  Row(user_id_str='75', user_screen_name='False', count=17),
#  Row(user_id_str='133804026', user_screen_name='RichPierce0079', count=16),
#  Row(user_id_str='362763757', user_screen_name='BillyTheBigBone', count=16),
#  Row(user_id_str='441572163', user_screen_name='Gentlemen_Sam', count=16),
#  Row(user_id_str='57', user_screen_name='False', count=15),
#  Row(user_id_str='14', user_screen_name='False', count=14),
#  Row(user_id_str='293447041', user_screen_name='Eva250178', count=14),
#  Row(user_id_str='587376186', user_screen_name='Localboy_Ash', count=14),
#  Row(user_id_str='720329744726687744', user_screen_name='saj44a', count=14),
#  Row(user_id_str='140738682', user_screen_name='anishsangamam', count=14),
#  Row(user_id_str='42205044', user_screen_name='basusagar', count=13),
#  Row(user_id_str='55', user_screen_name='False', count=13),
#  Row(user_id_str='64041474', user_screen_name='amruthhr', count=13),
#  Row(user_id_str='97', user_screen_name='False', count=13),
#  Row(user_id_str='154', user_screen_name='False', count=13),
#  Row(user_id_str='False', user_screen_name='India', count=13),
#  Row(user_id_str='21064452', user_screen_name='AW0079', count=13),
#  Row(user_id_str='3025478429', user_screen_name='ssbib85', count=13),
#  Row(user_id_str='444365106', user_screen_name='andzayn', count=13),
#  Row(user_id_str='30992650', user_screen_name='Mathew30', count=13),
#  Row(user_id_str='44', user_screen_name='False', count=13),
#  Row(user_id_str='14472490', user_screen_name='mcurie', count=12),
#  Row(user_id_str='23808818', user_screen_name='Brideofrocknrol', count=12),
#  Row(user_id_str='234', user_screen_name='False', count=12),
#  Row(user_id_str='149', user_screen_name='False', count=12),
#  Row(user_id_str='41', user_screen_name='False', count=12),
#  Row(user_id_str='20', user_screen_name='False', count=12),
#  Row(user_id_str='68', user_screen_name='False', count=12),
#  Row(user_id_str='62498968', user_screen_name='Asqwolf', count=12),
#  Row(user_id_str='271101710', user_screen_name='THEPIMPHACKER', count=12),
#  Row(user_id_str='96312930', user_screen_name='vishal2323', count=12),
#  Row(user_id_str='803555957733109760', user_screen_name='SpeakUp_IN', count=11),
#  Row(user_id_str='73937769', user_screen_name='See_i_can_fly', count=11),
#  Row(user_id_str='38', user_screen_name='False', count=11),
#  Row(user_id_str='710681467651624960', user_screen_name='happysach', count=11),
#  Row(user_id_str='493941380', user_screen_name='iamtrideep', count=11),
#  Row(user_id_str='126', user_screen_name='False', count=11),
#  Row(user_id_str='1217161502', user_screen_name='CourierZero', count=11),
#  Row(user_id_str='52', user_screen_name='False', count=11),
#  Row(user_id_str='3285473358', user_screen_name='iwritegarima', count=11),
#  Row(user_id_str='23', user_screen_name='False', count=11),
#  Row(user_id_str='157', user_screen_name='False', count=11),
#  Row(user_id_str='95', user_screen_name='False', count=11),
#  Row(user_id_str='83', user_screen_name='False', count=11),
#  Row(user_id_str='86029062', user_screen_name='siddiq10931093', count=11),
#  Row(user_id_str='787117533719560192', user_screen_name='dealsandloots', count=11),
#  Row(user_id_str='28', user_screen_name='False', count=11),
#  Row(user_id_str='2712332275', user_screen_name='SBillingtonfan', count=11),
#  Row(user_id_str='2892047065', user_screen_name='spradhan1210', count=11),
#  Row(user_id_str='32', user_screen_name='False', count=11),
#  Row(user_id_str='2366888623', user_screen_name='pranabdavinci', count=11),
#  Row(user_id_str='2305584128', user_screen_name='TyphHunter', count=11),
#  Row(user_id_str='483059773', user_screen_name='sky_regenrated', count=11),
#  Row(user_id_str='94', user_screen_name='False', count=11),
#  Row(user_id_str='272456715', user_screen_name='Mohan_Rngnathan', count=11),
#  Row(user_id_str='72', user_screen_name='False', count=10),
#  Row(user_id_str='1008060450', user_screen_name='Steph_CO7272', count=10),
#  Row(user_id_str='77', user_screen_name='False', count=10),
#  Row(user_id_str='2889927415', user_screen_name='Akshay_goplani', count=10),
#  Row(user_id_str='59', user_screen_name='False', count=10),
#  Row(user_id_str='15178679', user_screen_name='mcp111', count=10),
#  Row(user_id_str='271', user_screen_name='False', count=10),
#  Row(user_id_str='False', user_screen_name='2', count=10),
#  Row(user_id_str='54251727', user_screen_name='JimPierobon', count=10),
#  Row(user_id_str='63', user_screen_name='False', count=10),
#  Row(user_id_str='719544958877696001', user_screen_name='PritiYa80985097', count=10),
#  Row(user_id_str='12990382', user_screen_name='gwaland', count=10),
#  Row(user_id_str='22982668', user_screen_name='princessgleek', count=10),
#  Row(user_id_str='22', user_screen_name='False', count=10),
#  Row(user_id_str='705018428483112960', user_screen_name='MominSaifoddin', count=10),
#  Row(user_id_str='88', user_screen_name='False', count=10),
#  Row(user_id_str='70', user_screen_name='False', count=10),
#  Row(user_id_str='2868342566', user_screen_name='zyusoken', count=10),
#  Row(user_id_str='54528620', user_screen_name='linpswa', count=10),
#  Row(user_id_str='151', user_screen_name='False', count=10),
#  Row(user_id_str='346', user_screen_name='False', count=10),
#  Row(user_id_str='140', user_screen_name='False', count=10),
#  Row(user_id_str='29548628', user_screen_name='CarlosG67', count=9),
#  Row(user_id_str='241391028', user_screen_name='PRATHEESH_PPN', count=9),
#  Row(user_id_str='21', user_screen_name='False', count=9),
#  Row(user_id_str='42', user_screen_name='False', count=9),
#  Row(user_id_str='206', user_screen_name='False', count=9),
#  Row(user_id_str='15007269', user_screen_name='ckhayek', count=9),
#  Row(user_id_str='49989431', user_screen_name='NOtoGMOs', count=9),
#  Row(user_id_str='50', user_screen_name='False', count=9),
#  Row(user_id_str='111', user_screen_name='False', count=9),
#  Row(user_id_str='82', user_screen_name='False', count=9),
#  Row(user_id_str='845604400999661568', user_screen_name='DevjotN', count=9),
#  Row(user_id_str='307075287', user_screen_name='Heart1QueenBee', count=9),
#  Row(user_id_str='466818620', user_screen_name='musicxtu92', count=9),
#  Row(user_id_str='1300002864', user_screen_name='matthewD2013', count=9),
#  Row(user_id_str='23019151', user_screen_name='Bunnyaimee', count=9),
#  Row(user_id_str='33', user_screen_name='False', count=9),
#  Row(user_id_str='120410501', user_screen_name='RGengage', count=9),
#  Row(user_id_str='250321402', user_screen_name='meljridge', count=9),
#  Row(user_id_str='40', user_screen_name='False', count=9),
#  Row(user_id_str='3025211876', user_screen_name='353839052d72499', count=9),
#  Row(user_id_str='36', user_screen_name='False', count=9),
#  Row(user_id_str='74468092', user_screen_name='vaibhav926', count=9),
#  Row(user_id_str='125', user_screen_name='False', count=9),
#  Row(user_id_str='47828355', user_screen_name='CoCoButterExp', count=9),
#  Row(user_id_str='59203639', user_screen_name='Zaedlo', count=9),
#  Row(user_id_str='195', user_screen_name='False', count=9),
#  Row(user_id_str='143', user_screen_name='False', count=9),
#  Row(user_id_str='48', user_screen_name='False', count=9),
#  Row(user_id_str='17786914', user_screen_name='davecraige', count=9),
#  Row(user_id_str='235559055', user_screen_name='ikumarvinod', count=9),
#  Row(user_id_str='167', user_screen_name='False', count=9),
#  Row(user_id_str='48618530', user_screen_name='avocado__toast', count=9),
#  Row(user_id_str='174', user_screen_name='False', count=9),
#  Row(user_id_str='74', user_screen_name='False', count=8),
#  Row(user_id_str='115', user_screen_name='False', count=8),
#  Row(user_id_str='53', user_screen_name='False', count=8),
#  Row(user_id_str='213060183', user_screen_name='ke4ole1', count=8),
#  Row(user_id_str='4537041014', user_screen_name='vivivivi1307', count=8),
#  Row(user_id_str='66622722', user_screen_name='sanjanind', count=8),
#  Row(user_id_str='254', user_screen_name='False', count=8),
#  Row(user_id_str='176', user_screen_name='False', count=8),
#  Row(user_id_str='29', user_screen_name='False', count=8),
#  Row(user_id_str='57953914', user_screen_name='jeetendra25', count=8),
#  Row(user_id_str='364922032', user_screen_name='michelledefeo', count=8),
#  Row(user_id_str='351806152', user_screen_name='lewyitfc', count=8),
#  Row(user_id_str='134', user_screen_name='False', count=8),
#  Row(user_id_str='64', user_screen_name='False', count=8),
#  Row(user_id_str='321826849', user_screen_name='Lyanna_T', count=8),
#  Row(user_id_str='7', user_screen_name='False', count=8),
#  Row(user_id_str='False', user_screen_name='New Delhi, India', count=8),
#  Row(user_id_str='144', user_screen_name='False', count=8),
#  Row(user_id_str='218', user_screen_name='False', count=8),
#  Row(user_id_str='46', user_screen_name='False', count=8),
#  Row(user_id_str='25', user_screen_name='False', count=8),
#  Row(user_id_str='51120513', user_screen_name='jcline35', count=8),
#  Row(user_id_str='39935272', user_screen_name='Rookii24', count=8),
#  Row(user_id_str='52795609', user_screen_name='santaarnold', count=8),
#  Row(user_id_str='69', user_screen_name='False', count=8),
#  Row(user_id_str='13', user_screen_name='False', count=8),
#  Row(user_id_str='16', user_screen_name='False', count=8),
#  Row(user_id_str='28928956', user_screen_name='sudnigga', count=8),
#  Row(user_id_str='1387267123', user_screen_name='TheMimiZee', count=8),
#  Row(user_id_str='3003188510', user_screen_name='NathDeb2011', count=8),
#  Row(user_id_str='50616028', user_screen_name='amarlungare', count=8),
#  Row(user_id_str='172', user_screen_name='False', count=8),
#  Row(user_id_str='629354934', user_screen_name='elab49', count=8),
#  Row(user_id_str='86', user_screen_name='False', count=8),
#  Row(user_id_str='2855041037', user_screen_name='rusnewton98', count=8),
#  Row(user_id_str='187', user_screen_name='False', count=8),
#  Row(user_id_str='145', user_screen_name='False', count=8),
#  Row(user_id_str='116', user_screen_name='False', count=8),
#  Row(user_id_str='149477154', user_screen_name='rooniitdeb', count=8),
#  Row(user_id_str='228821192', user_screen_name='leighfuge', count=8),
#  Row(user_id_str='268', user_screen_name='False', count=8),
#  Row(user_id_str='26072340', user_screen_name='priskypaws', count=8),
#  Row(user_id_str='78', user_screen_name='False', count=8),
#  Row(user_id_str='754534205502136324', user_screen_name='avinevergiveup', count=8),
#  Row(user_id_str='153', user_screen_name='False', count=8),
#  Row(user_id_str='15805170', user_screen_name='dahnamchandler', count=8),
#  Row(user_id_str='450676096', user_screen_name='RITESHKHABIYA', count=8),
#  Row(user_id_str='18', user_screen_name='False', count=8),
#  Row(user_id_str='131310401', user_screen_name='PaulEPetty', count=8),
#  Row(user_id_str='315', user_screen_name='False', count=8),
#  Row(user_id_str='320', user_screen_name='False', count=8),
#  Row(user_id_str='173', user_screen_name='False', count=8),
#  Row(user_id_str='2304720642', user_screen_name='vikramwkarve', count=8),
#  Row(user_id_str='19', user_screen_name='False', count=8),
#  Row(user_id_str='69475762', user_screen_name='RedSixx', count=8),
#  Row(user_id_str='65', user_screen_name='False', count=8),
#  Row(user_id_str='41480905', user_screen_name='VofEscaflowne', count=8),
#  Row(user_id_str='3939183493', user_screen_name='rashmirawat2912', count=8),
#  Row(user_id_str='28020360', user_screen_name='JoeSiegler', count=8),
#  Row(user_id_str='57927491', user_screen_name='newproblem', count=8),
#  Row(user_id_str='146260629', user_screen_name='DementedWolfLuv', count=8),
#  Row(user_id_str='885336408', user_screen_name='J_cooper1990', count=8),
#  Row(user_id_str='73', user_screen_name='False', count=7),
#  Row(user_id_str='121', user_screen_name='False', count=7),
#  Row(user_id_str='2739775987', user_screen_name='Cypnos', count=7),
#  Row(user_id_str='3789082213', user_screen_name='2SixTwo', count=7),
#  Row(user_id_str='58237941', user_screen_name='Sparrargh', count=7),
#  Row(user_id_str='12', user_screen_name='False', count=7),
#  Row(user_id_str='4673571020', user_screen_name='deepak12may85', count=7),
#  Row(user_id_str='124', user_screen_name='False', count=7),
#  Row(user_id_str='79', user_screen_name='False', count=7),
#  Row(user_id_str='14486807', user_screen_name='msmitka', count=7),
#  Row(user_id_str='16275465', user_screen_name='TheMasterBaiter', count=7),
#  Row(user_id_str='71', user_screen_name='False', count=7),
#  Row(user_id_str='114', user_screen_name='False', count=7),
#  Row(user_id_str='147', user_screen_name='False', count=7),
#  Row(user_id_str='749383153937244164', user_screen_name='YoungPadawanPR', count=7),
#  Row(user_id_str='2991490598', user_screen_name='ssagardutta', count=7),
#  Row(user_id_str='201886488', user_screen_name='shoe3r', count=7),
#  Row(user_id_str='189', user_screen_name='False', count=7),
#  Row(user_id_str='113', user_screen_name='False', count=7),
#  Row(user_id_str='774275636101873668', user_screen_name='Nasruhllah07', count=7),
#  Row(user_id_str='813383712775684097', user_screen_name='Come_soondad', count=7),
#  Row(user_id_str='13765572', user_screen_name='hg6', count=7),
#  Row(user_id_str='130810999', user_screen_name='dhakaneram', count=7),
#  Row(user_id_str='AmazonHelp', user_screen_name='False', count=7),
#  Row(user_id_str='285222173', user_screen_name='neelanjanbarman', count=7),
#  Row(user_id_str='43', user_screen_name='False', count=7),
#  Row(user_id_str='30', user_screen_name='False', count=7),
#  Row(user_id_str='18435372', user_screen_name='medtek', count=7),
#  Row(user_id_str='212', user_screen_name='False', count=7),
#  Row(user_id_str='183', user_screen_name='False', count=7),
#  Row(user_id_str='88709529', user_screen_name='Tushi_Joy', count=7),
#  Row(user_id_str='706951793016590336', user_screen_name='Just_Me_Lauren', count=7),
#  Row(user_id_str='793273269222797312', user_screen_name='QuentinPotter3', count=7),
#  Row(user_id_str='1438180344', user_screen_name='iBasu07', count=7),
#  Row(user_id_str='488540026', user_screen_name='AshBurnOvrdrive', count=7),
#  Row(user_id_str='22346149', user_screen_name='shubhranshuu', count=7),
#  Row(user_id_str='6', user_screen_name='False', count=7),
#  Row(user_id_str='76', user_screen_name='False', count=7),
#  Row(user_id_str='305857840', user_screen_name='jademc120', count=7),
#  Row(user_id_str='14439544', user_screen_name='troykelly', count=7),
#  Row(user_id_str='51', user_screen_name='False', count=7),
#  Row(user_id_str='214', user_screen_name='False', count=7),
#  Row(user_id_str='43617802', user_screen_name='simonbangs', count=7),
#  Row(user_id_str='103', user_screen_name='False', count=7),
#  Row(user_id_str='169857536', user_screen_name='ateeqtak', count=7),
#  Row(user_id_str='47', user_screen_name='False', count=7),
#  Row(user_id_str='233', user_screen_name='False', count=7),
#  Row(user_id_str='2333955555', user_screen_name='Alfonsiawarrior', count=7),
#  Row(user_id_str='2439352879', user_screen_name='sonicman4321', count=7),
#  Row(user_id_str='235', user_screen_name='False', count=7),
#  Row(user_id_str='1164260107', user_screen_name='runsammrun', count=7),
#  Row(user_id_str='2243736468', user_screen_name='beautlittlefool', count=7),
#  Row(user_id_str='16678550', user_screen_name='librarykat', count=7),
#  Row(user_id_str='808456433872306177', user_screen_name='BuzzMcClain', count=7),
#  Row(user_id_str='26', user_screen_name='False', count=7),
#  Row(user_id_str='66302156', user_screen_name='TheZamindar', count=7),
#  Row(user_id_str='355860475', user_screen_name='RachelWhisker87', count=7),
#  Row(user_id_str='4893071304', user_screen_name='Mohitve75936435', count=7),
#  Row(user_id_str='2189027816', user_screen_name='DragonMcElroy', count=7),
#  Row(user_id_str='104', user_screen_name='False', count=7),
#  Row(user_id_str='146', user_screen_name='False', count=7),
#  Row(user_id_str='5723252', user_screen_name='boredgirl260', count=7),
#  Row(user_id_str='4707813086', user_screen_name='djiquad', count=7),
#  Row(user_id_str='2934257079', user_screen_name='Fz_Knuckle99', count=7),
#  Row(user_id_str='141', user_screen_name='False', count=7),
#  Row(user_id_str='78244428', user_screen_name='SAHAY7', count=7),
#  Row(user_id_str='144280479', user_screen_name='ReclusiveCoder', count=7),
#  Row(user_id_str='16851793', user_screen_name='kamleshrao', count=7),
#  Row(user_id_str='781106864939347968', user_screen_name='Roopa_Awesome', count=7),
#  Row(user_id_str='262', user_screen_name='False', count=7),
#  Row(user_id_str='False', user_screen_name='Mumbai, India', count=7),
#  Row(user_id_str='39395899', user_screen_name='flowmastr1x', count=7),
#  Row(user_id_str='61238575', user_screen_name='DanTup', count=7),
#  Row(user_id_str='230', user_screen_name='False', count=7),
#  Row(user_id_str='45876955', user_screen_name='ritarodwell', count=7),
#  Row(user_id_str='90', user_screen_name='False', count=7),
#  Row(user_id_str='66', user_screen_name='False', count=7),
#  Row(user_id_str='111182345', user_screen_name='Rohanhasastory', count=7),
#  Row(user_id_str='48357214', user_screen_name='nidhimaheshwari', count=7),
#  Row(user_id_str='1036308488', user_screen_name='nomnom_mania', count=7),
#  Row(user_id_str='829394625236443136', user_screen_name='DieselDragonIFD', count=7),
#  Row(user_id_str='283', user_screen_name='False', count=7),
#  Row(user_id_str='1272524941', user_screen_name='dilbil143', count=7),
#  Row(user_id_str='255806428', user_screen_name='Onestudpuppy', count=7),
#  Row(user_id_str='3411563867', user_screen_name='Harry_k3721', count=7),
#  Row(user_id_str='120', user_screen_name='False', count=7),
#  Row(user_id_str='80', user_screen_name='False', count=7),
#  Row(user_id_str='88726244', user_screen_name='sravan1802', count=7),
#  Row(user_id_str='74934167', user_screen_name='rucchir', count=7),
#  Row(user_id_str='37', user_screen_name='False', count=7),
#  Row(user_id_str='123', user_screen_name='False', count=7),
#  Row(user_id_str='458', user_screen_name='False', count=7),
#  Row(user_id_str='86762070', user_screen_name='lahsivarhor', count=7),
#  Row(user_id_str='142', user_screen_name='False', count=7),
#  Row(user_id_str='2200871844', user_screen_name='AgentDie', count=7),
#  Row(user_id_str='733028394', user_screen_name='EsmeraldaMollin', count=7),
#  Row(user_id_str='179', user_screen_name='False', count=7),
#  Row(user_id_str='1529167434', user_screen_name='RealMikeStack', count=7),
#  Row(user_id_str='385528206', user_screen_name='Taterpugz', count=7),
#  Row(user_id_str='112', user_screen_name='False', count=7),
#  Row(user_id_str='106', user_screen_name='False', count=7),
#  Row(user_id_str='3021485983', user_screen_name='Twitte2Ranga', count=7),
#  Row(user_id_str='737607555858325504', user_screen_name='Arthi305', count=7),
#  Row(user_id_str='122', user_screen_name='False', count=7),
#  Row(user_id_str='62', user_screen_name='False', count=7),
#  Row(user_id_str='192', user_screen_name='False', count=6),
#  Row(user_id_str='227', user_screen_name='False', count=6),
#  Row(user_id_str='439', user_screen_name='False', count=6),
#  Row(user_id_str='100613504', user_screen_name='sng628', count=6),
#  Row(user_id_str='527489415', user_screen_name='urvashi_mitra', count=6),
#  Row(user_id_str='3009368979', user_screen_name='ItsJustMe_Rae', count=6),
#  Row(user_id_str='280', user_screen_name='False', count=6),
#  Row(user_id_str='359869433', user_screen_name='DadaSiddharth', count=6),
#  Row(user_id_str='31232521', user_screen_name='IndusOrganics', count=6),
#  Row(user_id_str='69216275', user_screen_name='iamandeepdua', count=6),
#  Row(user_id_str='358', user_screen_name='False', count=6),
#  Row(user_id_str='17731339', user_screen_name='hfactor', count=6),
#  Row(user_id_str='148495262', user_screen_name='Whitjoseph', count=6),
#  Row(user_id_str='845145444', user_screen_name='PrasaadJoshi', count=6),
#  Row(user_id_str='14474054', user_screen_name='sureshmuthrotil', count=6),
#  Row(user_id_str='161', user_screen_name='False', count=6),
#  Row(user_id_str='225878277', user_screen_name='lupitasahu', count=6),
#  Row(user_id_str='76061012', user_screen_name='microrao', count=6),
#  Row(user_id_str='110', user_screen_name='False', count=6),
#  Row(user_id_str='46929510', user_screen_name='donna3939', count=6),
#  Row(user_id_str='18546339', user_screen_name='topgun1700', count=6),
#  Row(user_id_str='453958386', user_screen_name='krissna_krissna', count=6),
#  Row(user_id_str='413848234', user_screen_name='singhkislaya91', count=6),
#  Row(user_id_str='128', user_screen_name='False', count=6),
#  Row(user_id_str='131', user_screen_name='False', count=6),
#  Row(user_id_str='1195658958', user_screen_name='davyiphone', count=6),
#  Row(user_id_str='357062019', user_screen_name='Stjanm', count=6),
#  Row(user_id_str='101', user_screen_name='False', count=6),
#  Row(user_id_str='18863148', user_screen_name='SLAP_News', count=6),
#  Row(user_id_str='103913560', user_screen_name='Avisingh18', count=6),
#  Row(user_id_str='2284005775', user_screen_name='MyOregonLife', count=6),
#  Row(user_id_str='10813822', user_screen_name='NJShadow', count=6),
#  Row(user_id_str='246635943', user_screen_name='velsingakutty', count=6),
#  Row(user_id_str='54', user_screen_name='False', count=6),
#  Row(user_id_str='832057176', user_screen_name='Mike_Soldner', count=6),
#  Row(user_id_str='301', user_screen_name='False', count=6),
#  Row(user_id_str='3793634414', user_screen_name='chetan_cbe', count=6),
#  Row(user_id_str='3196478898', user_screen_name='UnsolicitedPM', count=6),
#  Row(user_id_str='69474850', user_screen_name='JelloBelle', count=6),
#  Row(user_id_str='769486341851615232', user_screen_name='MrArchitecht', count=6),
#  Row(user_id_str='35051582', user_screen_name='alluneediz1mik3', count=6),
#  Row(user_id_str='787171274200088576', user_screen_name='pinkigupta89', count=6),
#  Row(user_id_str='159', user_screen_name='False', count=6),
#  Row(user_id_str='5', user_screen_name='False', count=6),
#  Row(user_id_str='35214799', user_screen_name='coolfrog1988', count=6),
#  Row(user_id_str='170', user_screen_name='False', count=6),
#  Row(user_id_str='217', user_screen_name='False', count=6),
#  Row(user_id_str='758744557315993600', user_screen_name='Savvyy_Investor', count=6),
#  Row(user_id_str='49576954', user_screen_name='JanArrah', count=6),
#  Row(user_id_str='555028043', user_screen_name='Sportsionista', count=6),
#  Row(user_id_str='953947501', user_screen_name='Lunaborne', count=6),
#  Row(user_id_str='2153604350', user_screen_name='ghostbuster9999', count=6),
#  Row(user_id_str='744395344016879620', user_screen_name='music_theism', count=6),
#  Row(user_id_str='5979042', user_screen_name='imsvsims', count=6),
#  Row(user_id_str='14119630', user_screen_name='martinbrossman', count=6),
#  Row(user_id_str='237', user_screen_name='False', count=6),
#  Row(user_id_str='174820930', user_screen_name='GinBhandal', count=6),
#  Row(user_id_str='2414585990', user_screen_name='Ziggziee', count=6),
#  Row(user_id_str='194', user_screen_name='False', count=6),
#  Row(user_id_str='718856897730854912', user_screen_name='Hope4evamore', count=6),
#  Row(user_id_str='236470176', user_screen_name='cherehall', count=6),
#  Row(user_id_str='211798382', user_screen_name='Floydilicious', count=6),
#  Row(user_id_str='101964473', user_screen_name='khalidraza9', count=6),
#  Row(user_id_str='1607069072', user_screen_name='basmybasher', count=6),
#  Row(user_id_str='816037443468197892', user_screen_name='Kar4change', count=6),
#  Row(user_id_str='165301682', user_screen_name='Jcamps30', count=6),
#  Row(user_id_str='922302955', user_screen_name='VEMVintage', count=6),
#  Row(user_id_str='332', user_screen_name='False', count=6),
#  Row(user_id_str='112763444', user_screen_name='cpriyanko', count=6),
#  Row(user_id_str='923435816', user_screen_name='IpsitaRichi', count=6),
#  Row(user_id_str='149912101', user_screen_name='vaishalimitra', count=6),
#  Row(user_id_str='714942588', user_screen_name='deecaltee', count=6),
#  Row(user_id_str='1904765227', user_screen_name='BHAVITA8', count=6),
#  Row(user_id_str='173377262', user_screen_name='xtye_', count=6),
#  Row(user_id_str='328', user_screen_name='False', count=6),
#  Row(user_id_str='14654682', user_screen_name='hardeep1singh', count=6),
#  Row(user_id_str='19336157', user_screen_name='Robgoblin', count=6),
#  Row(user_id_str='73544761', user_screen_name='_KylaMarie_', count=6),
#  Row(user_id_str='543571642', user_screen_name='ranabiswanath12', count=6),
#  Row(user_id_str='53624188', user_screen_name='only4ojha', count=6),
#  Row(user_id_str='100214244', user_screen_name='sourabhnandwana', count=6),
#  Row(user_id_str='13232092', user_screen_name='ebuie', count=6),
#  Row(user_id_str='19168933', user_screen_name='waldvogelk', count=6),
#  Row(user_id_str='96', user_screen_name='False', count=6),
#  Row(user_id_str='27', user_screen_name='False', count=6),
#  Row(user_id_str='36101298', user_screen_name='BhavinTolia', count=6),
#  Row(user_id_str='130535139', user_screen_name='DeirdreWriter', count=6),
#  Row(user_id_str='204', user_screen_name='False', count=6),
#  Row(user_id_str='1589344782', user_screen_name='briancyork', count=6),
#  Row(user_id_str='367', user_screen_name='False', count=6),
#  Row(user_id_str='40552570', user_screen_name='KnittedLamb', count=6),
#  Row(user_id_str='117630515', user_screen_name='Ronnie_hul', count=6),
#  Row(user_id_str='188', user_screen_name='False', count=6),
#  Row(user_id_str='838703000516497408', user_screen_name='AshishK90634189', count=6),
#  Row(user_id_str='865938712005365760', user_screen_name='pankajpeshavari', count=6),
#  Row(user_id_str='144122115', user_screen_name='divyesh_tamboli', count=6),
#  Row(user_id_str='239', user_screen_name='False', count=6),
#  Row(user_id_str='277305534', user_screen_name='Music_lupe', count=6),
#  Row(user_id_str='312', user_screen_name='False', count=6),
#  Row(user_id_str='559425755', user_screen_name='kjhabak', count=6),
#  Row(user_id_str='325670927', user_screen_name='Manjunath_Bhat_', count=6),
#  Row(user_id_str='81629063', user_screen_name='ramscrism', count=6),
#  Row(user_id_str='134300648', user_screen_name='project_gonzo', count=6),
#  Row(user_id_str='284157036', user_screen_name='drmjp93', count=6),
#  Row(user_id_str='125675649', user_screen_name='txomon', count=6),
#  Row(user_id_str='534', user_screen_name='False', count=6),
#  Row(user_id_str='19649319', user_screen_name='sixfishesphilly', count=6),
#  Row(user_id_str='1118337270', user_screen_name='Ronakjobanputr1', count=6),
#  Row(user_id_str='562366927', user_screen_name='FatimaSiraja', count=6),
#  Row(user_id_str='801462165345550337', user_screen_name='voxya_', count=6),
#  Row(user_id_str='93', user_screen_name='False', count=6),
#  Row(user_id_str='17463956', user_screen_name='Tushar_Kapila', count=6),
#  Row(user_id_str='125549164', user_screen_name='atreyee21', count=6),
#  Row(user_id_str='127111907', user_screen_name='BionicBombshell', count=6),
#  Row(user_id_str='3462186912', user_screen_name='krishi_89', count=6),
#  Row(user_id_str='14415645', user_screen_name='ooSteph', count=6),
#  Row(user_id_str='4892425227', user_screen_name='craigr98_2016', count=6),
#  Row(user_id_str='45', user_screen_name='False', count=6),
#  Row(user_id_str='460', user_screen_name='False', count=6),
#  Row(user_id_str='128657766', user_screen_name='anthjamre', count=6),
#  Row(user_id_str='466384851', user_screen_name='Green_JamesBee', count=6),
#  Row(user_id_str='102', user_screen_name='False', count=6),
#  Row(user_id_str='2698629504', user_screen_name='SarthakMaiti', count=6),
#  Row(user_id_str='2993286430', user_screen_name='ThatBallerKru', count=6),
#  Row(user_id_str='252', user_screen_name='False', count=6),
#  Row(user_id_str='1852139480', user_screen_name='mileyfan2017', count=6),
#  Row(user_id_str='837835207', user_screen_name='fightwonegames', count=6),
#  Row(user_id_str='356', user_screen_name='False', count=6),
#  Row(user_id_str='3006076339', user_screen_name='TechyFarooqui', count=6),
#  Row(user_id_str='136895681', user_screen_name='_danielchris', count=6),
#  Row(user_id_str='388738029', user_screen_name='kmayyank', count=6),
#  Row(user_id_str='3233722514', user_screen_name='FootBaller121', count=6),
#  Row(user_id_str='14751142', user_screen_name='dabassman', count=6),
#  Row(user_id_str='171', user_screen_name='False', count=6),
#  Row(user_id_str='306', user_screen_name='False', count=6),
#  Row(user_id_str='127', user_screen_name='False', count=6),
#  Row(user_id_str='424400406', user_screen_name='brian_riback', count=6),
#  Row(user_id_str='11702402', user_screen_name='trallyus', count=6),
#  Row(user_id_str='593127032', user_screen_name='vickram_chandak', count=6),
#  Row(user_id_str='119', user_screen_name='False', count=6),
#  Row(user_id_str='253', user_screen_name='False', count=6),
#  Row(user_id_str='125365751', user_screen_name='swapnil_rk', count=6),
#  Row(user_id_str='199', user_screen_name='False', count=6),
#  Row(user_id_str='19619272', user_screen_name='robinminkpiss', count=6),
#  Row(user_id_str='3055235056', user_screen_name='manicminaj', count=6),
#  Row(user_id_str='28090061', user_screen_name='Krriztin', count=6),
#  Row(user_id_str='19191538', user_screen_name='JoeMedal', count=6),
#  Row(user_id_str='23068174', user_screen_name='ash_mcloone', count=6),
#  Row(user_id_str='1399965709', user_screen_name='MrsSardines', count=6),
#  Row(user_id_str='249787502', user_screen_name='callsignemily', count=6),
#  Row(user_id_str='163877633', user_screen_name='Trainer_CRM', count=6),
#  Row(user_id_str='1191703062', user_screen_name='forthereading', count=6),
#  Row(user_id_str='2223516397', user_screen_name='NuroDev', count=6),
#  Row(user_id_str='35', user_screen_name='False', count=6),
#  Row(user_id_str='186', user_screen_name='False', count=6),
#  Row(user_id_str='14205478', user_screen_name='CactoKaur', count=6),
#  Row(user_id_str='789691149459914752', user_screen_name='orion_613', count=6),
#  Row(user_id_str='98', user_screen_name='False', count=6),
#  Row(user_id_str='2380038870', user_screen_name='iAshishPrasad', count=6),
#  Row(user_id_str='704181213334937601', user_screen_name='Bescent28', count=6),
#  Row(user_id_str='49263856', user_screen_name='SunnyKinger', count=6),
#  Row(user_id_str='3143395706', user_screen_name='heetshah97', count=6),
#  Row(user_id_str='61149346', user_screen_name='Musashi1596', count=6),
#  Row(user_id_str='817699501293129728', user_screen_name='knepp_lindsey', count=6),
#  Row(user_id_str='163', user_screen_name='False', count=6),
#  Row(user_id_str='1138113037', user_screen_name='MacqueenNathan', count=6),
#  Row(user_id_str='311', user_screen_name='False', count=6),
#  Row(user_id_str='148', user_screen_name='False', count=6),
#  Row(user_id_str='137', user_screen_name='False', count=6),
#  Row(user_id_str='1075158410', user_screen_name='meganbongo', count=6),
#  Row(user_id_str='168', user_screen_name='False', count=6),
#  Row(user_id_str='61606664', user_screen_name='VinayK1991', count=6),
#  Row(user_id_str='44812007', user_screen_name='mad_ashish', count=6),
#  Row(user_id_str='17', user_screen_name='False', count=6),
#  Row(user_id_str='223', user_screen_name='False', count=6),
#  Row(user_id_str='248', user_screen_name='False', count=6),
#  Row(user_id_str='87', user_screen_name='False', count=6),
#  Row(user_id_str='10', user_screen_name='False', count=6),
#  Row(user_id_str='269', user_screen_name='False', count=6),
#  Row(user_id_str='1542918302', user_screen_name='Suruchi0603', count=6),
#  Row(user_id_str=None, user_screen_name=' ', count=6),
#  Row(user_id_str='181', user_screen_name='False', count=6),
#  Row(user_id_str='301381979', user_screen_name='AndyMRoberts', count=6),
#  Row(user_id_str='159797979', user_screen_name='praveenhak', count=6),
#  Row(user_id_str='330', user_screen_name='False', count=6),
#  Row(user_id_str='455398854', user_screen_name='chelseaepenney', count=6),
#  Row(user_id_str='1559903875', user_screen_name='manojk2209', count=6),
#  Row(user_id_str='3032469392', user_screen_name='Romilvora111199', count=6),
#  Row(user_id_str='3403856709', user_screen_name='PattyPeppermynt', count=6),
#  Row(user_id_str='4805069673', user_screen_name='Vaderundead', count=6),
#  Row(user_id_str='1064415878', user_screen_name='AkiraSakura2', count=6),
#  Row(user_id_str='267676234', user_screen_name='GG_s0nic', count=6),
#  Row(user_id_str='505481011', user_screen_name='tanujrawat1', count=6),
#  Row(user_id_str='595548720', user_screen_name='iAmSmi__', count=6),
#  Row(user_id_str='133460244', user_screen_name='Tilbo_Tweets', count=6),
#  Row(user_id_str='270375787', user_screen_name='NATFXDA', count=6),
#  Row(user_id_str='118', user_screen_name='False', count=6),
#  Row(user_id_str='1066180207', user_screen_name='posterest', count=6),
#  Row(user_id_str='969815922', user_screen_name='gokulkrishnen', count=6),
#  Row(user_id_str='2214869341', user_screen_name='jeujeubeee', count=5),
#  Row(user_id_str='2219985456', user_screen_name='nadu_bda', count=5),
#  Row(user_id_str='47584774', user_screen_name='jordanwaring87', count=5),
#  Row(user_id_str='415', user_screen_name='False', count=5),
#  Row(user_id_str='1666520694', user_screen_name='LalwaniNiraj', count=5),
#  Row(user_id_str='630450707', user_screen_name='roadshowrigolet', count=5),
#  Row(user_id_str='382', user_screen_name='False', count=5),
#  Row(user_id_str='224', user_screen_name='False', count=5),
#  Row(user_id_str='187257670', user_screen_name='mehulsthakker', count=5),
#  Row(user_id_str='903272676', user_screen_name='bijender393', count=5),
#  Row(user_id_str='429', user_screen_name='False', count=5),
#  Row(user_id_str='162', user_screen_name='False', count=5),
#  Row(user_id_str='865160440250105857', user_screen_name='jitenderboss202', count=5),
#  Row(user_id_str='780511623425458176', user_screen_name='ItsTxcker', count=5),
#  Row(user_id_str='150', user_screen_name='False', count=5),
#  Row(user_id_str='878312518103384065', user_screen_name='tulsyan_mayank', count=5),
#  Row(user_id_str='35591749', user_screen_name='TCMuffin', count=5),
#  Row(user_id_str='29962012', user_screen_name='i_fernando', count=5),
#  Row(user_id_str='71302070', user_screen_name='arifkhan7', count=5),
#  Row(user_id_str='334489387', user_screen_name='gauthamrandom', count=5),
#  Row(user_id_str='False', user_screen_name='London', count=5),
#  Row(user_id_str='17527115', user_screen_name='BeyondGrave', count=5),
#  Row(user_id_str='27842803', user_screen_name='aisforarlynne', count=5),
#  Row(user_id_str='250214902', user_screen_name='GothboyUK', count=5),
#  Row(user_id_str='45323163', user_screen_name='Trafficspinners', count=5),
#  Row(user_id_str='23456146', user_screen_name='SouthernScenic', count=5),
#  Row(user_id_str='136182379', user_screen_name='sidd15121987', count=5),
#  Row(user_id_str='24237942', user_screen_name='5thLineTalent', count=5),
#  Row(user_id_str='108798356', user_screen_name='nellemel', count=5),
#  Row(user_id_str='401286522', user_screen_name='Gutta_DaDon', count=5),
#  Row(user_id_str='2', user_screen_name='False', count=5),
#  Row(user_id_str='3372380115', user_screen_name='DigitlScientist', count=5),
#  Row(user_id_str='40869710', user_screen_name='McQuaidKP', count=5),
#  Row(user_id_str='1672102627', user_screen_name='IamMelly03', count=5),
#  Row(user_id_str='15454963', user_screen_name='bawbag', count=5),
#  Row(user_id_str='4384021696', user_screen_name='Nihit_maverick', count=5),
#  Row(user_id_str='347', user_screen_name='False', count=5),
#  Row(user_id_str='26619513', user_screen_name='SausageofPower', count=5),
#  Row(user_id_str='238', user_screen_name='False', count=5),
#  Row(user_id_str='100339412', user_screen_name='bigcomedown', count=5),
#  Row(user_id_str='25689668', user_screen_name='fadari', count=5),
#  Row(user_id_str='156', user_screen_name='False', count=5),
#  Row(user_id_str='454', user_screen_name='False', count=5),
#  Row(user_id_str='23558756', user_screen_name='AryanIndians', count=5),
#  Row(user_id_str='4113185435', user_screen_name='JohnDso64841345', count=5),
#  Row(user_id_str='45457886', user_screen_name='iamcorrupt', count=5),
#  Row(user_id_str='16101134', user_screen_name='omshivaprakash', count=5),
#  Row(user_id_str='11920632', user_screen_name='maxpowley', count=5),
#  Row(user_id_str='2259952085', user_screen_name='chetansmith11', count=5),
#  Row(user_id_str='302', user_screen_name='False', count=5),
#  Row(user_id_str='809748623512596480', user_screen_name='PumpkinPieYum', count=5),
#  Row(user_id_str='52804269', user_screen_name='Er_Snk', count=5),
#  Row(user_id_str='480', user_screen_name='False', count=5),
#  Row(user_id_str='200108931', user_screen_name='cjmitra', count=5),
#  Row(user_id_str='4676764704', user_screen_name='SardarGurvinde2', count=5),
#  Row(user_id_str='445', user_screen_name='False', count=5),
#  Row(user_id_str='267381861', user_screen_name='SparklyPen', count=5),
#  Row(user_id_str='148808815', user_screen_name='Hungrypunjabi', count=5),
#  Row(user_id_str='856953860', user_screen_name='IvanHotrod', count=5),
#  Row(user_id_str='209', user_screen_name='False', count=5),
#  Row(user_id_str='160073361', user_screen_name='neerajap3', count=5),
#  Row(user_id_str='574', user_screen_name='False', count=5),
#  Row(user_id_str='59146973', user_screen_name='crazybadkid', count=5),
#  Row(user_id_str='20546310', user_screen_name='havanaclub_soda', count=5),
#  Row(user_id_str='387', user_screen_name='False', count=5),
#  Row(user_id_str='746249790569254912', user_screen_name='birdskylife', count=5),
#  Row(user_id_str='141962835', user_screen_name='vikijain87', count=5),
#  Row(user_id_str='99', user_screen_name='False', count=5),
#  Row(user_id_str='2487134674', user_screen_name='bridyid5', count=5),
#  Row(user_id_str='133653438', user_screen_name='chaudhary93', count=5),
#  Row(user_id_str='39', user_screen_name='False', count=5),
#  Row(user_id_str='319521142', user_screen_name='brajeshjee', count=5),
#  Row(user_id_str='23352195', user_screen_name='gmosesl', count=5),
#  Row(user_id_str='149236006', user_screen_name='RuddyglowPark', count=5),
#  Row(user_id_str='156359057', user_screen_name='SCTrojanSK', count=5),
#  Row(user_id_str='36412139', user_screen_name='YiannisNennes', count=5),
#  Row(user_id_str='18638692', user_screen_name='DavidELever', count=5),
#  Row(user_id_str='110354554', user_screen_name='praveen_pandey_', count=5),
#  Row(user_id_str='204431120', user_screen_name='sundevesh', count=5),
#  Row(user_id_str='18234839', user_screen_name='torreddaytona', count=5),
#  Row(user_id_str='33560945', user_screen_name='skmahtab', count=5),
#  Row(user_id_str='152', user_screen_name='False', count=5),
#  Row(user_id_str='360', user_screen_name='False', count=5),
#  Row(user_id_str='2953652983', user_screen_name='abhishekr2323', count=5),
#  Row(user_id_str='836849147244339200', user_screen_name='tuteja_shruti', count=5),
#  Row(user_id_str='151039885', user_screen_name='IMRANKHANMOGUL', count=5),
#  Row(user_id_str='128634987', user_screen_name='Subharanjan_', count=5),
#  Row(user_id_str='3979623264', user_screen_name='Uttam20Uttam', count=5),
#  Row(user_id_str='329318603', user_screen_name='Kevin_Ellen_', count=5),
#  Row(user_id_str='196', user_screen_name='False', count=5),
#  Row(user_id_str='26564556', user_screen_name='BananeJen', count=5),
#  Row(user_id_str='185219338', user_screen_name='bigbamee', count=5),
#  Row(user_id_str='378520650', user_screen_name='divakardas22', count=5),
#  Row(user_id_str='814372928695521280', user_screen_name='remakoul', count=5),
#  Row(user_id_str='4889990293', user_screen_name='iGoneViral', count=5),
#  Row(user_id_str='165', user_screen_name='False', count=5),
#  Row(user_id_str='371', user_screen_name='False', count=5),
#  Row(user_id_str='84', user_screen_name='False', count=5),
#  Row(user_id_str='799358397367877632', user_screen_name='theachopsbooks', count=5),
#  Row(user_id_str='205727959', user_screen_name='jaidevd', count=5),
#  Row(user_id_str='1426939406', user_screen_name='AshitMr', count=5),
#  Row(user_id_str='144723151', user_screen_name='juancvasdisenho', count=5),
#  Row(user_id_str='20422796', user_screen_name='playmaker09', count=5),
#  Row(user_id_str='705971208', user_screen_name='alyciadebdamnn', count=5),
#  Row(user_id_str='21901245', user_screen_name='bkel', count=5),
#  Row(user_id_str='1027098103', user_screen_name='B_Lachani', count=5),
#  Row(user_id_str='44823152', user_screen_name='peerlesspig', count=5),
#  Row(user_id_str='137106484', user_screen_name='AziizaT', count=5),
#  Row(user_id_str='2467103148', user_screen_name='Tower_Tramp', count=5),
#  Row(user_id_str='37534186', user_screen_name='RCausey', count=5),
#  Row(user_id_str='62705229', user_screen_name='Ahmed_Awad1212', count=5),
#  Row(user_id_str='3711696145', user_screen_name='Dharmendrakasa', count=5),
#  Row(user_id_str='538549155', user_screen_name='TaiKamiya101', count=5),
#  Row(user_id_str='15920461', user_screen_name='thicker', count=5),
#  Row(user_id_str='2643486098', user_screen_name='sumantvasan', count=5),
#  Row(user_id_str='2953709027', user_screen_name='AmyUnitedStates', count=5),
#  Row(user_id_str='511351188', user_screen_name='ConorMX', count=5),
#  Row(user_id_str='1893356316', user_screen_name='sidartsidart', count=5),
#  Row(user_id_str='279387044', user_screen_name='ankitpalsri', count=5),
#  Row(user_id_str='14907839', user_screen_name='tarunpunwani', count=5),
#  Row(user_id_str='456358376', user_screen_name='revanusha', count=5),
#  Row(user_id_str='272', user_screen_name='False', count=5),
#  Row(user_id_str='20391647', user_screen_name='SkullyRox', count=5),
#  Row(user_id_str='209702451', user_screen_name='CobaltHailstorm', count=5),
#  Row(user_id_str='598538099', user_screen_name='Tdam3Trey', count=5),
#  Row(user_id_str='14565884', user_screen_name='ShakataGaNai', count=5),
#  Row(user_id_str='34984337', user_screen_name='degr4ssi', count=5),
#  Row(user_id_str='38803772', user_screen_name='bala43212', count=5),
#  Row(user_id_str='2237735712', user_screen_name='WanderThatMews', count=5),
#  Row(user_id_str='2154418802', user_screen_name='bhandary_chirag', count=5),
#  Row(user_id_str='866684497546231808', user_screen_name='Rajeshk76856612', count=5),
#  Row(user_id_str='144921369', user_screen_name='CervantesAndres', count=5),
#  Row(user_id_str='434138083', user_screen_name='CregorNews', count=5),
#  Row(user_id_str='339848271', user_screen_name='MrDeckotron', count=5),
#  Row(user_id_str='17701394', user_screen_name='anaggh', count=5),
#  Row(user_id_str='38289347', user_screen_name='ellenseabell', count=5),
#  Row(user_id_str='113516042', user_screen_name='whisperandmoan', count=5),
#  Row(user_id_str='73097498', user_screen_name='hd_nemesis', count=5),
#  Row(user_id_str='1959501074', user_screen_name='uncensoredpen', count=5),
#  Row(user_id_str='912722124', user_screen_name='shipra_im', count=5),
#  Row(user_id_str='579', user_screen_name='False', count=5),
#  Row(user_id_str='False', user_screen_name='Bengaluru, India', count=5),
#  Row(user_id_str='136', user_screen_name='False', count=5),
#  Row(user_id_str='121318872', user_screen_name='jaxiwest', count=5),
#  Row(user_id_str='161778392', user_screen_name='sagar3225', count=5),
#  Row(user_id_str='1608365852', user_screen_name='shivanient1998', count=5),
#  Row(user_id_str='43970870', user_screen_name='BrightBetty', count=5),
#  Row(user_id_str='396890520', user_screen_name='azkite', count=5),
#  Row(user_id_str='205931698', user_screen_name='pratitimajumdar', count=5),
#  Row(user_id_str='45820389', user_screen_name='C6RDE', count=5),
#  Row(user_id_str='2308798004', user_screen_name='windroidica', count=5),
#  Row(user_id_str='4853775889', user_screen_name='gramopadhye1971', count=5),
#  Row(user_id_str='170667264', user_screen_name='RyanWSinclair', count=5),
#  Row(user_id_str='833230601779949568', user_screen_name='Paulbissac1', count=5),
#  Row(user_id_str='2322387605', user_screen_name='GTIMKVII', count=5),
#  Row(user_id_str='2317805748', user_screen_name='ElliottBros1', count=5),
#  Row(user_id_str='434800262', user_screen_name='JiteshChhabria', count=5),
#  Row(user_id_str='12275422', user_screen_name='johnomalley', count=5),
#  Row(user_id_str='280859344', user_screen_name='Mahimd7', count=5),
#  Row(user_id_str='20790669', user_screen_name='paulstevenlewis', count=5),
#  Row(user_id_str='822177', user_screen_name='tvjames', count=5),
#  Row(user_id_str='3322188248', user_screen_name='kgaurav00', count=5),
#  Row(user_id_str='206642342', user_screen_name='Tillums', count=5),
#  Row(user_id_str='223961574', user_screen_name='ltweetl', count=5),
#  Row(user_id_str='32137033', user_screen_name='firstbascia', count=5),
#  Row(user_id_str='314445868', user_screen_name='likhilpunjabi', count=5),
#  Row(user_id_str='43557159', user_screen_name='Spartan_029', count=5),
#  Row(user_id_str='26064052', user_screen_name='ajaygupta1974', count=5),
#  Row(user_id_str='95945333', user_screen_name='Speechlesstx', count=5),
#  Row(user_id_str='264', user_screen_name='False', count=5),
#  Row(user_id_str='619427787', user_screen_name='OfficialPiyush', count=5),
#  Row(user_id_str='145153049', user_screen_name='jjackson235', count=5),
#  Row(user_id_str='30256180', user_screen_name='RaghavKhunger', count=5),
#  Row(user_id_str='2800223095', user_screen_name='jenniespary', count=5),
#  Row(user_id_str='1149358428', user_screen_name='HarrietPH', count=5),
#  Row(user_id_str='2427928976', user_screen_name='magicalwife', count=5),
#  Row(user_id_str='733116597825495040', user_screen_name='Alokzgh', count=5),
#  Row(user_id_str='4925825782', user_screen_name='mgpjz', count=5),
#  Row(user_id_str='282', user_screen_name='False', count=5),
#  Row(user_id_str='19919515', user_screen_name='BenMyatt74', count=5),
#  Row(user_id_str='1967676368', user_screen_name='EDGAurora', count=5),
#  Row(user_id_str='3252507746', user_screen_name='KSean02', count=5),
#  Row(user_id_str='786518369155506176', user_screen_name='chakam_uday', count=5),
#  Row(user_id_str='1157191909', user_screen_name='pallabrout', count=5),
#  Row(user_id_str='300813035', user_screen_name='cocobobi', count=5),
#  Row(user_id_str='16543736', user_screen_name='manchicken', count=5),
#  Row(user_id_str='3081841793', user_screen_name='Kam_54321', count=5),
#  Row(user_id_str='259779047', user_screen_name='MissSmallVoice', count=5),
#  Row(user_id_str='99273069', user_screen_name='RISSHHII', count=5),
#  Row(user_id_str='321', user_screen_name='False', count=5),
#  Row(user_id_str='2347968828', user_screen_name='OctavioDelano', count=5),
#  Row(user_id_str='60', user_screen_name='False', count=5),
#  Row(user_id_str='762435621633744896', user_screen_name='nsvaluto74', count=5),
#  Row(user_id_str='14293184', user_screen_name='nrosier', count=5),
#  Row(user_id_str='740456791176253441', user_screen_name='Soko_nafuu', count=5),
#  Row(user_id_str='3165014492', user_screen_name='realvishalraj', count=5),
#  Row(user_id_str='1227418134', user_screen_name='rishabgundecha', count=5),
#  Row(user_id_str='15195593', user_screen_name='LadySlaughter', count=5),
#  Row(user_id_str='902137872', user_screen_name='mybharatraj', count=5),
#  Row(user_id_str='104268993', user_screen_name='MyApocalypse_', count=5),
#  Row(user_id_str='295334669', user_screen_name='roxyunderwood93', count=5),
#  Row(user_id_str='223342603', user_screen_name='JustCIDER', count=5),
#  Row(user_id_str='21041619', user_screen_name='RobynCobbold', count=5),
#  Row(user_id_str='827805937771503616', user_screen_name='HKhatale', count=5),
#  Row(user_id_str='298', user_screen_name='False', count=5),
#  Row(user_id_str='95693303', user_screen_name='rohitvatwani', count=5),
#  Row(user_id_str='2530034064', user_screen_name='SameeraShairali', count=5),
#  Row(user_id_str='826080295711625217', user_screen_name='SanghviHarshraj', count=5),
#  Row(user_id_str='17194863', user_screen_name='patriciaeff', count=5),
#  Row(user_id_str='293677963', user_screen_name='Horrorfan419', count=5),
#  Row(user_id_str='355088719', user_screen_name='varun_ar', count=5),
#  Row(user_id_str='2932058297', user_screen_name='ColdXzero', count=5),
#  Row(user_id_str='284', user_screen_name='False', count=5),
#  Row(user_id_str='16193077', user_screen_name='chickenb00', count=5),
#  Row(user_id_str='138', user_screen_name='False', count=5),
#  Row(user_id_str='76584269', user_screen_name='destiny4ever2u', count=5),
#  Row(user_id_str='170130930', user_screen_name='BlackBerry_Mama', count=5),
#  Row(user_id_str='49', user_screen_name='False', count=5),
#  Row(user_id_str='66870413', user_screen_name='JerseyStupka', count=5),
#  Row(user_id_str='278977971', user_screen_name='AjeetKarn', count=5),
#  Row(user_id_str='162316823', user_screen_name='itzmepravesh', count=5),
#  Row(user_id_str='43828556', user_screen_name='balagopalks', count=5),
#  Row(user_id_str='129266889', user_screen_name='maximum_z', count=5),
#  Row(user_id_str='1426285704', user_screen_name='GirlGamer7', count=5),
#  Row(user_id_str='862074670174138368', user_screen_name='DscoJesus', count=5),
#  Row(user_id_str='3219027614', user_screen_name='caprasul', count=5),
#  Row(user_id_str='20082414', user_screen_name='JohnBloorDesign', count=5),
#  Row(user_id_str='107', user_screen_name='False', count=5),
#  Row(user_id_str='16276284', user_screen_name='Torresxs', count=5),
#  Row(user_id_str='81', user_screen_name='False', count=5),
#  Row(user_id_str='727477608011571200', user_screen_name='neerajt1971', count=5),
#  Row(user_id_str='3309102108', user_screen_name='MtnrMS', count=5),
#  Row(user_id_str='3243729912', user_screen_name='NakulKaushik88', count=5),
#  Row(user_id_str='44329735', user_screen_name='yadavsaid', count=5),
#  Row(user_id_str='4719402324', user_screen_name='SubratShasank', count=5),
#  Row(user_id_str='38064765', user_screen_name='Cena_316_AA', count=5),
#  Row(user_id_str='21336479', user_screen_name='cherrydoll1', count=5),
#  Row(user_id_str='1639136594', user_screen_name='consultantweet', count=5),
#  Row(user_id_str='164', user_screen_name='False', count=5),
#  Row(user_id_str='2397772844', user_screen_name='SmitSuv', count=5),
#  Row(user_id_str='31', user_screen_name='False', count=5),
#  Row(user_id_str='amazonIN', user_screen_name='False', count=5),
#  Row(user_id_str='83187396', user_screen_name='ontherocks66', count=5),
#  Row(user_id_str='40248562', user_screen_name='catloverplayer', count=5),
#  Row(user_id_str='46228767', user_screen_name='ewanandfriends', count=5),
#  Row(user_id_str='283892690', user_screen_name='nickmorrott', count=5),
#  Row(user_id_str='22171741', user_screen_name='TheTreavor', count=5),
#  Row(user_id_str='764352385', user_screen_name='gautammahajan11', count=5),
#  Row(user_id_str='250', user_screen_name='False', count=5),
#  Row(user_id_str='126438609', user_screen_name='FinalGamerJames', count=5),
#  Row(user_id_str='130872938', user_screen_name='tarunwadhwa198', count=5),
#  Row(user_id_str='622890534', user_screen_name='richardin1956', count=5),
#  Row(user_id_str='876124662', user_screen_name='mayankvj2406', count=5),
#  Row(user_id_str='39124778', user_screen_name='Kristen_Howe', count=5),
#  Row(user_id_str='553607147', user_screen_name='PrateekP789', count=5),
#  Row(user_id_str='878192295987867648', user_screen_name='Shakirfahim1', count=5),
#  Row(user_id_str='2811807426', user_screen_name='hartsway', count=5),
#  Row(user_id_str='706032993794527232', user_screen_name='ChaurasiaRohin', count=5),
#  Row(user_id_str='744511861', user_screen_name='inderpreet_83', count=5),
#  Row(user_id_str='116341095', user_screen_name='kamala_chan', count=5),
#  Row(user_id_str='4452075193', user_screen_name='Karthikeyapisup', count=5),
#  Row(user_id_str='57275846', user_screen_name='mee_ind', count=5),
#  Row(user_id_str='2268638768', user_screen_name='PrateekMarlecha', count=5),
#  Row(user_id_str='433', user_screen_name='False', count=5),
#  Row(user_id_str='129854185', user_screen_name='PrashantBiyani', count=5),
#  Row(user_id_str='273', user_screen_name='False', count=5),
#  Row(user_id_str='48402117', user_screen_name='amit1407', count=5),
#  Row(user_id_str='False', user_screen_name='4', count=5),
#  Row(user_id_str='351', user_screen_name='False', count=5),
#  Row(user_id_str='4189195819', user_screen_name='i_opner', count=5),
#  Row(user_id_str='26787826', user_screen_name='theghostofkip', count=5),
#  Row(user_id_str='92', user_screen_name='False', count=5),
#  Row(user_id_str='4860411251', user_screen_name='Lozza2285', count=5),
#  Row(user_id_str='1341265634', user_screen_name='Amez_W', count=5),
#  Row(user_id_str='14932406', user_screen_name='zegolf', count=5),
#  Row(user_id_str='16939507', user_screen_name='aniawit', count=5),
#  Row(user_id_str='95690710', user_screen_name='Bunny_spy', count=5),
#  Row(user_id_str='586301042', user_screen_name='adit_morzaria', count=5),
#  Row(user_id_str='2983836055', user_screen_name='JohnMFurlong', count=5),
#  Row(user_id_str='2233372459', user_screen_name='vickyappy30', count=5),
#  Row(user_id_str='117622520', user_screen_name='DanielToner', count=5),
#  Row(user_id_str='3068784488', user_screen_name='VlSlT', count=5),
#  Row(user_id_str='225815970', user_screen_name='sakethabhi', count=5),
#  Row(user_id_str='214049826', user_screen_name='AmpersUK', count=5),
#  Row(user_id_str='68398349', user_screen_name='yktalks', count=5),
#  Row(user_id_str='444', user_screen_name='False', count=5),
#  Row(user_id_str='85', user_screen_name='False', count=5),
#  Row(user_id_str='180361172', user_screen_name='VK_231', count=5),
#  Row(user_id_str='323019713', user_screen_name='UDTMac', count=5),
#  Row(user_id_str='827375319208300544', user_screen_name='pagetbrewster', count=5),
#  Row(user_id_str='310987276', user_screen_name='KaranJaswani1', count=5),
#  Row(user_id_str='79844395', user_screen_name='ncazals', count=5),
#  Row(user_id_str='15351491', user_screen_name='markkorput', count=5),
#  Row(user_id_str='58', user_screen_name='False', count=5),
#  Row(user_id_str='24', user_screen_name='False', count=5),
#  Row(user_id_str='100468594', user_screen_name='opjha', count=5),
#  Row(user_id_str='97826794', user_screen_name='lalitsurana', count=5),
#  Row(user_id_str='False', user_screen_name='3', count=5),
#  Row(user_id_str='436', user_screen_name='False', count=5),
#  Row(user_id_str='126275079', user_screen_name='x_Th3_Truth_x', count=5),
#  Row(user_id_str='1608794084', user_screen_name='Careermappersd', count=5),
#  Row(user_id_str='21651074', user_screen_name='neonladder', count=5),
#  Row(user_id_str='139301405', user_screen_name='nelle_belle91', count=5),
#  Row(user_id_str='1079912580', user_screen_name='ON8CB', count=5),
#  Row(user_id_str='2842757176', user_screen_name='kimmisearle', count=5),
#  Row(user_id_str='30924249', user_screen_name='The89thGuardian', count=5),
#  Row(user_id_str='727534589468532736', user_screen_name='vision_ogl', count=5),
#  Row(user_id_str='112759451', user_screen_name='pxlshftr', count=5),
#  Row(user_id_str='130613237', user_screen_name='hamzaazam92', count=5),
#  Row(user_id_str='1543185697', user_screen_name='Aosc2', count=5),
#  Row(user_id_str='2227128248', user_screen_name='KVas92103', count=5),
#  Row(user_id_str='61', user_screen_name='False', count=5),
#  Row(user_id_str='110745877', user_screen_name='PhilippaJG', count=5),
#  Row(user_id_str='34803492', user_screen_name='Kalekemo', count=5),
#  Row(user_id_str='2479531801', user_screen_name='KumarPraval', count=5),
#  Row(user_id_str='4908895821', user_screen_name='shahidiqbal0007', count=5),
#  Row(user_id_str='122783695', user_screen_name='Gemx86x', count=5),
#  Row(user_id_str='25275742', user_screen_name='antidumb', count=5),
#  Row(user_id_str='166893639', user_screen_name='kaimal_hari', count=5),
#  Row(user_id_str='158', user_screen_name='False', count=5),
#  Row(user_id_str='108', user_screen_name='False', count=5),
#  Row(user_id_str='89440799', user_screen_name='Pixie_Jaime', count=5),
#  Row(user_id_str='86746815', user_screen_name='jdg2310', count=5),
#  Row(user_id_str='299', user_screen_name='False', count=5),
#  Row(user_id_str='966683100', user_screen_name='JanHCAFC', count=5),
#  Row(user_id_str='4146949275', user_screen_name='0xJAKE', count=5),
#  Row(user_id_str='19192576', user_screen_name='rheird', count=5),
#  Row(user_id_str='1282432266', user_screen_name='Shadowslightz', count=5),
#  Row(user_id_str='2341184034', user_screen_name='caffdtravels', count=5),
#  Row(user_id_str='449211149', user_screen_name='notarelys', count=5),
#  Row(user_id_str='17535421', user_screen_name='RapidBI', count=5),
#  Row(user_id_str='2210976025', user_screen_name='kagarg90', count=5),
#  Row(user_id_str='2922164726', user_screen_name='Awesomichael23', count=5),
#  Row(user_id_str='137944902', user_screen_name='netajee', count=5),
#  Row(user_id_str='812028824', user_screen_name='JennyCavanaugh', count=5),
#  Row(user_id_str='246', user_screen_name='False', count=5),
#  Row(user_id_str='526010652', user_screen_name='That_Musician', count=5),
#  Row(user_id_str='65833857', user_screen_name='ravinderkum1191', count=5),
#  Row(user_id_str='2835021711', user_screen_name='KirrrrstyLight', count=5),
#  Row(user_id_str='200206858', user_screen_name='Sulalee1', count=5),
#  Row(user_id_str='934064701', user_screen_name='apurba_s', count=5),
#  Row(user_id_str='2302732471', user_screen_name='Urban_struggle', count=5),
#  Row(user_id_str='791166101006585857', user_screen_name='r_narayan11', count=5),
#  Row(user_id_str='276563438', user_screen_name='Mindful2move', count=5),
#  Row(user_id_str='913138646', user_screen_name='SmileyTutorials', count=5),
#  Row(user_id_str='3171120559', user_screen_name='i3isystem', count=5),
#  Row(user_id_str='132', user_screen_name='False', count=5),
#  Row(user_id_str='833534991493636096', user_screen_name='thekoreankappa', count=5),
#  Row(user_id_str='776791812123930625', user_screen_name='Hpykumar', count=5),
#  Row(user_id_str='286242688', user_screen_name='topsurveys', count=5),
#  Row(user_id_str='148468753', user_screen_name='LaborneRacing', count=5),
#  Row(user_id_str='3315608602', user_screen_name='Abhinav1bansal', count=5),
#  Row(user_id_str='6575472', user_screen_name='wdowell', count=5),
#  Row(user_id_str='383170468', user_screen_name='MrsPTeach', count=5),
#  Row(user_id_str='8017352', user_screen_name='navdeepsoni', count=5),
#  Row(user_id_str='773346', user_screen_name='JonBenditz', count=5),
#  Row(user_id_str='844239138769551361', user_screen_name='Rakesh2132017', count=5),
#  Row(user_id_str='101568093', user_screen_name='dkutka25', count=5)]

# %%
AB_Test_id = spark.sparkContext.textFile('experiment.txt')

# %%
type(AB_Test_id)
# Out:
# pyspark.rdd.RDD

# %%
from pyspark.sql import Row
row = Row("user_id_str")

# %%
AB_Test_Dataframe = AB_Test_id.map(row).toDF()

# %%
AB_Test_Dataframe
# Out:
# DataFrame[user_id_str: string]

# %%
AB_Test_Dataframe.first()
# Out:
# Row(user_id_str='143515471')

# %%
AB_Test_Dataframe.show(5)
# Out:
# +-----------+
# |user_id_str|
# +-----------+
# |  143515471|
# |   85741735|
# |   71457972|
# | 2908108256|
# |  106799492|
# +-----------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import lit

# %%
experiment_user_dummy = AB_Test_Dataframe.withColumn('Whether_active',lit(None).cast(StringType()))

# %%
experiment_user_dummy.count()
# Out:
# 5000

# %%
experiment_user_dummy.first()
# Out:
# Row(user_id_str='143515471', Whether_active=None)

# %%
sqlContext.registerDataFrameAsTable(experiment_user_dummy, "table_1")
sqlContext.registerDataFrameAsTable(df1, "table_2")

# %%
ans = sqlContext.sql("Select t1.user_id_str,t1.Whether_active,t2.user_id_str as other,t2.user_screen_name from table_1 as t1  left join table_2 as t2 on t1.user_id_str = t2.user_id_str")

# %%
len(ans.collect())
# Out:
# 5000

# %%
sqlContext.registerDataFrameAsTable(ans, "table")

# %%
experiment_user = sqlContext.sql('Select user_id_str, CASE when other is NULL then \'NO \' else \'YES \' END as whether_active from table')

# %%
experiment_user.collect()
# Out:
# [Row(user_id_str='143515471', whether_active='NO '),
#  Row(user_id_str='85741735', whether_active='YES '),
#  Row(user_id_str='71457972', whether_active='NO '),
#  Row(user_id_str='2908108256', whether_active='NO '),
#  Row(user_id_str='106799492', whether_active='NO '),
#  Row(user_id_str='59156981', whether_active='NO '),
#  Row(user_id_str='902137872', whether_active='YES '),
#  Row(user_id_str='110354554', whether_active='YES '),
#  Row(user_id_str='97424433', whether_active='NO '),
#  Row(user_id_str='62364020', whether_active='NO '),
#  Row(user_id_str='2706101936', whether_active='NO '),
#  Row(user_id_str='5654472', whether_active='NO '),
#  Row(user_id_str='145579921', whether_active='NO '),
#  Row(user_id_str='2502172122', whether_active='NO '),
#  Row(user_id_str='243716471', whether_active='NO '),
#  Row(user_id_str='2610379644', whether_active='NO '),
#  Row(user_id_str='123138418', whether_active='NO '),
#  Row(user_id_str='257376764', whether_active='NO '),
#  Row(user_id_str='269145593', whether_active='NO '),
#  Row(user_id_str='370711133', whether_active='NO '),
#  Row(user_id_str='1510968974', whether_active='NO '),
#  Row(user_id_str='3526380922', whether_active='NO '),
#  Row(user_id_str='163413904', whether_active='NO '),
#  Row(user_id_str='16980347', whether_active='NO '),
#  Row(user_id_str='1209614366', whether_active='NO '),
#  Row(user_id_str='447433286', whether_active='NO '),
#  Row(user_id_str='1970607968', whether_active='NO '),
#  Row(user_id_str='3285473358', whether_active='YES '),
#  Row(user_id_str='1112166661', whether_active='NO '),
#  Row(user_id_str='422175328', whether_active='NO '),
#  Row(user_id_str='60004557', whether_active='NO '),
#  Row(user_id_str='2789430008', whether_active='NO '),
#  Row(user_id_str='253242925', whether_active='NO '),
#  Row(user_id_str='141214344', whether_active='NO '),
#  Row(user_id_str='24787056', whether_active='NO '),
#  Row(user_id_str='22830586', whether_active='NO '),
#  Row(user_id_str='138605435', whether_active='NO '),
#  Row(user_id_str='2199664468', whether_active='NO '),
#  Row(user_id_str='71098947', whether_active='NO '),
#  Row(user_id_str='174156582', whether_active='NO '),
#  Row(user_id_str='315105182', whether_active='NO '),
#  Row(user_id_str='356667027', whether_active='NO '),
#  Row(user_id_str='152122529', whether_active='NO '),
#  Row(user_id_str='300526090', whether_active='NO '),
#  Row(user_id_str='281666367', whether_active='NO '),
#  Row(user_id_str='314200747', whether_active='NO '),
#  Row(user_id_str='284371894', whether_active='NO '),
#  Row(user_id_str='193060294', whether_active='NO '),
#  Row(user_id_str='3098204839', whether_active='NO '),
#  Row(user_id_str='89107116', whether_active='NO '),
#  Row(user_id_str='20815886', whether_active='NO '),
#  Row(user_id_str='3157739056', whether_active='NO '),
#  Row(user_id_str='768680968114667520', whether_active='NO '),
#  Row(user_id_str='460620990', whether_active='NO '),
#  Row(user_id_str='1379501556', whether_active='NO '),
#  Row(user_id_str='2725725450', whether_active='NO '),
#  Row(user_id_str='55165270', whether_active='NO '),
#  Row(user_id_str='252708604', whether_active='NO '),
#  Row(user_id_str='94245683', whether_active='NO '),
#  Row(user_id_str='33686448', whether_active='NO '),
#  Row(user_id_str='238576433', whether_active='NO '),
#  Row(user_id_str='518389533', whether_active='NO '),
#  Row(user_id_str='21217122', whether_active='NO '),
#  Row(user_id_str='791732926387884032', whether_active='NO '),
#  Row(user_id_str='132216274', whether_active='NO '),
#  Row(user_id_str='175322072', whether_active='NO '),
#  Row(user_id_str='29949567', whether_active='NO '),
#  Row(user_id_str='17130680', whether_active='NO '),
#  Row(user_id_str='1194213805', whether_active='NO '),
#  Row(user_id_str='356677104', whether_active='NO '),
#  Row(user_id_str='173697045', whether_active='NO '),
#  Row(user_id_str='13785352', whether_active='NO '),
#  Row(user_id_str='1034809063', whether_active='NO '),
#  Row(user_id_str='182037498', whether_active='NO '),
#  Row(user_id_str='2326748376', whether_active='NO '),
#  Row(user_id_str='2351435020', whether_active='NO '),
#  Row(user_id_str='4111464136', whether_active='NO '),
#  Row(user_id_str='2229240523', whether_active='NO '),
#  Row(user_id_str='2402058558', whether_active='NO '),
#  Row(user_id_str='77321410', whether_active='NO '),
#  Row(user_id_str='3375721527', whether_active='NO '),
#  Row(user_id_str='860495726', whether_active='NO '),
#  Row(user_id_str='3923649083', whether_active='NO '),
#  Row(user_id_str='31467003', whether_active='NO '),
#  Row(user_id_str='4146493673', whether_active='NO '),
#  Row(user_id_str='43189449', whether_active='NO '),
#  Row(user_id_str='14348618', whether_active='NO '),
#  Row(user_id_str='191873398', whether_active='NO '),
#  Row(user_id_str='14169855', whether_active='NO '),
#  Row(user_id_str='103596643', whether_active='NO '),
#  Row(user_id_str='87690895', whether_active='NO '),
#  Row(user_id_str='382901851', whether_active='NO '),
#  Row(user_id_str='506067767', whether_active='NO '),
#  Row(user_id_str='323149948', whether_active='NO '),
#  Row(user_id_str='2348808775', whether_active='NO '),
#  Row(user_id_str='32071786', whether_active='NO '),
#  Row(user_id_str='89633357', whether_active='NO '),
#  Row(user_id_str='375712053', whether_active='NO '),
#  Row(user_id_str='2816704757', whether_active='NO '),
#  Row(user_id_str='720331094', whether_active='NO '),
#  Row(user_id_str='349381846', whether_active='NO '),
#  Row(user_id_str='418871874', whether_active='NO '),
#  Row(user_id_str='16657113', whether_active='NO '),
#  Row(user_id_str='102688383', whether_active='NO '),
#  Row(user_id_str='772544294137630720', whether_active='NO '),
#  Row(user_id_str='1399965709', whether_active='YES '),
#  Row(user_id_str='826284212', whether_active='NO '),
#  Row(user_id_str='3196213653', whether_active='NO '),
#  Row(user_id_str='4442301695', whether_active='NO '),
#  Row(user_id_str='1485862291', whether_active='NO '),
#  Row(user_id_str='294719044', whether_active='NO '),
#  Row(user_id_str='468731640', whether_active='NO '),
#  Row(user_id_str='8408412', whether_active='NO '),
#  Row(user_id_str='786212672194813953', whether_active='NO '),
#  Row(user_id_str='81000458', whether_active='NO '),
#  Row(user_id_str='578426523', whether_active='NO '),
#  Row(user_id_str='2847886928', whether_active='NO '),
#  Row(user_id_str='258080946', whether_active='NO '),
#  Row(user_id_str='2293516421', whether_active='NO '),
#  Row(user_id_str='3073354949', whether_active='NO '),
#  Row(user_id_str='2244751172', whether_active='NO '),
#  Row(user_id_str='1648631244', whether_active='NO '),
#  Row(user_id_str='207114132', whether_active='NO '),
#  Row(user_id_str='155809091', whether_active='NO '),
#  Row(user_id_str='48395069', whether_active='NO '),
#  Row(user_id_str='41337472', whether_active='NO '),
#  Row(user_id_str='50902973', whether_active='NO '),
#  Row(user_id_str='588605404', whether_active='NO '),
#  Row(user_id_str='591804599', whether_active='NO '),
#  Row(user_id_str='1806671', whether_active='NO '),
#  Row(user_id_str='2551073557', whether_active='NO '),
#  Row(user_id_str='2663928969', whether_active='NO '),
#  Row(user_id_str='19315352', whether_active='NO '),
#  Row(user_id_str='585782554', whether_active='NO '),
#  Row(user_id_str='63707171', whether_active='NO '),
#  Row(user_id_str='1655530248', whether_active='NO '),
#  Row(user_id_str='277408746', whether_active='NO '),
#  Row(user_id_str='1283793956', whether_active='NO '),
#  Row(user_id_str='437669623', whether_active='NO '),
#  Row(user_id_str='205418510', whether_active='NO '),
#  Row(user_id_str='270940424', whether_active='NO '),
#  Row(user_id_str='700332933119414272', whether_active='NO '),
#  Row(user_id_str='2025531', whether_active='NO '),
#  Row(user_id_str='44678898', whether_active='NO '),
#  Row(user_id_str='203597952', whether_active='NO '),
#  Row(user_id_str='1957347541', whether_active='NO '),
#  Row(user_id_str='599445692', whether_active='NO '),
#  Row(user_id_str='3398096555', whether_active='NO '),
#  Row(user_id_str='323274346', whether_active='NO '),
#  Row(user_id_str='248931197', whether_active='NO '),
#  Row(user_id_str='21267682', whether_active='NO '),
#  Row(user_id_str='197598528', whether_active='NO '),
#  Row(user_id_str='1689125262', whether_active='NO '),
#  Row(user_id_str='17824489', whether_active='NO '),
#  Row(user_id_str='118378294', whether_active='NO '),
#  Row(user_id_str='282269833', whether_active='NO '),
#  Row(user_id_str='134152350', whether_active='NO '),
#  Row(user_id_str='3234664235', whether_active='NO '),
#  Row(user_id_str='36679173', whether_active='NO '),
#  Row(user_id_str='4755678875', whether_active='NO '),
#  Row(user_id_str='2322987994', whether_active='NO '),
#  Row(user_id_str='190543244', whether_active='NO '),
#  Row(user_id_str='15519893', whether_active='NO '),
#  Row(user_id_str='543872908', whether_active='NO '),
#  Row(user_id_str='14454583', whether_active='NO '),
#  Row(user_id_str='1040604872', whether_active='NO '),
#  Row(user_id_str='625542640', whether_active='NO '),
#  Row(user_id_str='1170556975', whether_active='NO '),
#  Row(user_id_str='3342756442', whether_active='NO '),
#  Row(user_id_str='17665654', whether_active='NO '),
#  Row(user_id_str='6295782', whether_active='NO '),
#  Row(user_id_str='380538425', whether_active='NO '),
#  Row(user_id_str='236301546', whether_active='NO '),
#  Row(user_id_str='19775711', whether_active='NO '),
#  Row(user_id_str='623948688', whether_active='NO '),
#  Row(user_id_str='156131053', whether_active='NO '),
#  Row(user_id_str='878083386', whether_active='NO '),
#  Row(user_id_str='1264262994', whether_active='NO '),
#  Row(user_id_str='20075370', whether_active='NO '),
#  Row(user_id_str='64556019', whether_active='NO '),
#  Row(user_id_str='162682950', whether_active='NO '),
#  Row(user_id_str='472271131', whether_active='NO '),
#  Row(user_id_str='491426468', whether_active='NO '),
#  Row(user_id_str='302051431', whether_active='NO '),
#  Row(user_id_str='76047938', whether_active='NO '),
#  Row(user_id_str='23019151', whether_active='YES '),
#  Row(user_id_str='214587100', whether_active='NO '),
#  Row(user_id_str='735237505', whether_active='NO '),
#  Row(user_id_str='19563380', whether_active='NO '),
#  Row(user_id_str='15075643', whether_active='NO '),
#  Row(user_id_str='2820871918', whether_active='NO '),
#  Row(user_id_str='319029300', whether_active='NO '),
#  Row(user_id_str='2911144645', whether_active='NO '),
#  Row(user_id_str='167129822', whether_active='NO '),
#  Row(user_id_str='2178554890', whether_active='NO '),
#  Row(user_id_str='28931985', whether_active='NO '),
#  Row(user_id_str='377527019', whether_active='NO '),
#  Row(user_id_str='14735760', whether_active='NO '),
#  Row(user_id_str='89900424', whether_active='NO '),
#  Row(user_id_str='219930660', whether_active='NO '),
#  Row(user_id_str='446742802', whether_active='NO '),
#  Row(user_id_str='39078109', whether_active='NO '),
#  Row(user_id_str='125855207', whether_active='NO '),
#  Row(user_id_str='70389188', whether_active='NO '),
#  Row(user_id_str='22915745', whether_active='NO '),
#  Row(user_id_str='1196145949', whether_active='NO '),
#  Row(user_id_str='168418392', whether_active='NO '),
#  Row(user_id_str='2698629504', whether_active='YES '),
#  Row(user_id_str='718033847930097664', whether_active='NO '),
#  Row(user_id_str='3023752657', whether_active='NO '),
#  Row(user_id_str='82018203', whether_active='NO '),
#  Row(user_id_str='716687022719676416', whether_active='NO '),
#  Row(user_id_str='65332022', whether_active='NO '),
#  Row(user_id_str='141121479', whether_active='NO '),
#  Row(user_id_str='38640756', whether_active='NO '),
#  Row(user_id_str='3877071439', whether_active='NO '),
#  Row(user_id_str='48626994', whether_active='NO '),
#  Row(user_id_str='133856231', whether_active='NO '),
#  Row(user_id_str='102119049', whether_active='NO '),
#  Row(user_id_str='4380411', whether_active='NO '),
#  Row(user_id_str='4417845858', whether_active='NO '),
#  Row(user_id_str='2322723822', whether_active='NO '),
#  Row(user_id_str='145940316', whether_active='NO '),
#  Row(user_id_str='787616782148366336', whether_active='NO '),
#  Row(user_id_str='2347212330', whether_active='NO '),
#  Row(user_id_str='74678948', whether_active='NO '),
#  Row(user_id_str='478954545', whether_active='NO '),
#  Row(user_id_str='305560776', whether_active='NO '),
#  Row(user_id_str='2193433592', whether_active='NO '),
#  Row(user_id_str='1240846296', whether_active='NO '),
#  Row(user_id_str='3304100556', whether_active='NO '),
#  Row(user_id_str='715810118', whether_active='NO '),
#  Row(user_id_str='4593154519', whether_active='NO '),
#  Row(user_id_str='102578904', whether_active='NO '),
#  Row(user_id_str='755649698921345024', whether_active='NO '),
#  Row(user_id_str='791304923841388544', whether_active='NO '),
#  Row(user_id_str='317698183', whether_active='NO '),
#  Row(user_id_str='768738865', whether_active='NO '),
#  Row(user_id_str='793458123344261120', whether_active='NO '),
#  Row(user_id_str='40692308', whether_active='NO '),
#  Row(user_id_str='14430913', whether_active='NO '),
#  Row(user_id_str='3250864230', whether_active='NO '),
#  Row(user_id_str='374735949', whether_active='NO '),
#  Row(user_id_str='156302205', whether_active='NO '),
#  Row(user_id_str='14961827', whether_active='NO '),
#  Row(user_id_str='89237396', whether_active='NO '),
#  Row(user_id_str='741872860407431168', whether_active='NO '),
#  Row(user_id_str='72877928', whether_active='NO '),
#  Row(user_id_str='1908777942', whether_active='NO '),
#  Row(user_id_str='56210818', whether_active='NO '),
#  Row(user_id_str='20973783', whether_active='NO '),
#  Row(user_id_str='2228056004', whether_active='NO '),
#  Row(user_id_str='1210875679', whether_active='NO '),
#  Row(user_id_str='450442747', whether_active='NO '),
#  Row(user_id_str='2316449398', whether_active='NO '),
#  Row(user_id_str='54311555', whether_active='NO '),
#  Row(user_id_str='14993218', whether_active='NO '),
#  Row(user_id_str='57322834', whether_active='NO '),
#  Row(user_id_str='158632671', whether_active='NO '),
#  Row(user_id_str='705020775166685184', whether_active='NO '),
#  Row(user_id_str='83078534', whether_active='NO '),
#  Row(user_id_str='221125308', whether_active='NO '),
#  Row(user_id_str='1914640352', whether_active='NO '),
#  Row(user_id_str='255935729', whether_active='NO '),
#  Row(user_id_str='147258286', whether_active='NO '),
#  Row(user_id_str='21338481', whether_active='NO '),
#  Row(user_id_str='156365299', whether_active='NO '),
#  Row(user_id_str='122672833', whether_active='NO '),
#  Row(user_id_str='127216617', whether_active='NO '),
#  Row(user_id_str='29684260', whether_active='NO '),
#  Row(user_id_str='61218672', whether_active='NO '),
#  Row(user_id_str='25151772', whether_active='NO '),
#  Row(user_id_str='2171855560', whether_active='NO '),
#  Row(user_id_str='284075387', whether_active='NO '),
#  Row(user_id_str='1110962058', whether_active='NO '),
#  Row(user_id_str='396796435', whether_active='NO '),
#  Row(user_id_str='62872680', whether_active='NO '),
#  Row(user_id_str='71302070', whether_active='YES '),
#  Row(user_id_str='1231247078', whether_active='NO '),
#  Row(user_id_str='365367615', whether_active='NO '),
#  Row(user_id_str='127186083', whether_active='NO '),
#  Row(user_id_str='81329096', whether_active='NO '),
#  Row(user_id_str='278516937', whether_active='NO '),
#  Row(user_id_str='40713544', whether_active='NO '),
#  Row(user_id_str='158471550', whether_active='NO '),
#  Row(user_id_str='620214487', whether_active='NO '),
#  Row(user_id_str='2981676459', whether_active='NO '),
#  Row(user_id_str='769833799098241024', whether_active='NO '),
#  Row(user_id_str='296995839', whether_active='NO '),
#  Row(user_id_str='255946292', whether_active='NO '),
#  Row(user_id_str='175756541', whether_active='NO '),
#  Row(user_id_str='373275893', whether_active='NO '),
#  Row(user_id_str='249190612', whether_active='NO '),
#  Row(user_id_str='163148814', whether_active='NO '),
#  Row(user_id_str='180361172', whether_active='YES '),
#  Row(user_id_str='24655213', whether_active='NO '),
#  Row(user_id_str='17424831', whether_active='NO '),
#  Row(user_id_str='1603957266', whether_active='NO '),
#  Row(user_id_str='51013278', whether_active='NO '),
#  Row(user_id_str='20343872', whether_active='NO '),
#  Row(user_id_str='488190692', whether_active='NO '),
#  Row(user_id_str='3064134913', whether_active='NO '),
#  Row(user_id_str='792489392455708672', whether_active='NO '),
#  Row(user_id_str='136371386', whether_active='NO '),
#  Row(user_id_str='485556712', whether_active='NO '),
#  Row(user_id_str='2471882927', whether_active='NO '),
#  Row(user_id_str='291033211', whether_active='NO '),
#  Row(user_id_str='1432265624', whether_active='NO '),
#  Row(user_id_str='206062743', whether_active='NO '),
#  Row(user_id_str='255430770', whether_active='NO '),
#  Row(user_id_str='493941380', whether_active='YES '),
#  Row(user_id_str='1347081', whether_active='NO '),
#  Row(user_id_str='3811502293', whether_active='NO '),
#  Row(user_id_str='2688190572', whether_active='NO '),
#  Row(user_id_str='15488009', whether_active='NO '),
#  Row(user_id_str='58875334', whether_active='NO '),
#  Row(user_id_str='75980633', whether_active='NO '),
#  Row(user_id_str='720811218508849152', whether_active='NO '),
#  Row(user_id_str='4366491613', whether_active='NO '),
#  Row(user_id_str='257320677', whether_active='NO '),
#  Row(user_id_str='228025464', whether_active='NO '),
#  Row(user_id_str='613496890', whether_active='NO '),
#  Row(user_id_str='53454531', whether_active='NO '),
#  Row(user_id_str='156664343', whether_active='NO '),
#  Row(user_id_str='789256404', whether_active='NO '),
#  Row(user_id_str='107008766', whether_active='NO '),
#  Row(user_id_str='453590509', whether_active='NO '),
#  Row(user_id_str='317774985', whether_active='NO '),
#  Row(user_id_str='280370764', whether_active='NO '),
#  Row(user_id_str='1148946805', whether_active='NO '),
#  Row(user_id_str='106843636', whether_active='NO '),
#  Row(user_id_str='780110020461596672', whether_active='NO '),
#  Row(user_id_str='180854053', whether_active='NO '),
#  Row(user_id_str='54751476', whether_active='NO '),
#  Row(user_id_str='25976103', whether_active='NO '),
#  Row(user_id_str='2685131954', whether_active='NO '),
#  Row(user_id_str='554493417', whether_active='NO '),
#  Row(user_id_str='16031661', whether_active='NO '),
#  Row(user_id_str='540223123', whether_active='NO '),
#  Row(user_id_str='79266671', whether_active='NO '),
#  Row(user_id_str='786911784045256704', whether_active='NO '),
#  Row(user_id_str='265069320', whether_active='NO '),
#  Row(user_id_str='227558783', whether_active='NO '),
#  Row(user_id_str='425825960', whether_active='NO '),
#  Row(user_id_str='3459096634', whether_active='NO '),
#  Row(user_id_str='98434540', whether_active='NO '),
#  Row(user_id_str='540744250', whether_active='NO '),
#  Row(user_id_str='91804415', whether_active='NO '),
#  Row(user_id_str='21998279', whether_active='NO '),
#  Row(user_id_str='19280072', whether_active='NO '),
#  Row(user_id_str='15604020', whether_active='NO '),
#  Row(user_id_str='96721010', whether_active='NO '),
#  Row(user_id_str='11892672', whether_active='NO '),
#  Row(user_id_str='142243378', whether_active='NO '),
#  Row(user_id_str='42747982', whether_active='NO '),
#  Row(user_id_str='20039132', whether_active='NO '),
#  Row(user_id_str='446149900', whether_active='NO '),
#  Row(user_id_str='137685030', whether_active='NO '),
#  Row(user_id_str='793273269222797312', whether_active='YES '),
#  Row(user_id_str='84306077', whether_active='NO '),
#  Row(user_id_str='129433156', whether_active='NO '),
#  Row(user_id_str='453209717', whether_active='NO '),
#  Row(user_id_str='50972311', whether_active='NO '),
#  Row(user_id_str='929624545', whether_active='NO '),
#  Row(user_id_str='14244836', whether_active='NO '),
#  Row(user_id_str='376854086', whether_active='NO '),
#  Row(user_id_str='84115838', whether_active='NO '),
#  Row(user_id_str='234641258', whether_active='NO '),
#  Row(user_id_str='2463479774', whether_active='NO '),
#  Row(user_id_str='401160259', whether_active='NO '),
#  Row(user_id_str='383083991', whether_active='NO '),
#  Row(user_id_str='160500308', whether_active='NO '),
#  Row(user_id_str='156226234', whether_active='NO '),
#  Row(user_id_str='1443351012', whether_active='NO '),
#  Row(user_id_str='1705468489', whether_active='NO '),
#  Row(user_id_str='763375765253652480', whether_active='NO '),
#  Row(user_id_str='319457278', whether_active='NO '),
#  Row(user_id_str='68657683', whether_active='NO '),
#  Row(user_id_str='793640186504581120', whether_active='NO '),
#  Row(user_id_str='106795900', whether_active='NO '),
#  Row(user_id_str='4548191940', whether_active='NO '),
#  Row(user_id_str='2174216995', whether_active='NO '),
#  Row(user_id_str='2219985456', whether_active='YES '),
#  Row(user_id_str='4176798072', whether_active='NO '),
#  Row(user_id_str='180331674', whether_active='NO '),
#  Row(user_id_str='92895763', whether_active='NO '),
#  Row(user_id_str='2193608857', whether_active='NO '),
#  Row(user_id_str='39454604', whether_active='NO '),
#  Row(user_id_str='1255519657', whether_active='NO '),
#  Row(user_id_str='1655129347', whether_active='NO '),
#  Row(user_id_str='1675908295', whether_active='NO '),
#  Row(user_id_str='46408133', whether_active='NO '),
#  Row(user_id_str='170651537', whether_active='NO '),
#  Row(user_id_str='14725241', whether_active='NO '),
#  Row(user_id_str='37907842', whether_active='NO '),
#  Row(user_id_str='43406190', whether_active='NO '),
#  Row(user_id_str='259875880', whether_active='NO '),
#  Row(user_id_str='2865599865', whether_active='NO '),
#  Row(user_id_str='2395197084', whether_active='NO '),
#  Row(user_id_str='26475128', whether_active='NO '),
#  Row(user_id_str='298791247', whether_active='NO '),
#  Row(user_id_str='34930255', whether_active='NO '),
#  Row(user_id_str='1188929052', whether_active='NO '),
#  Row(user_id_str='2210273923', whether_active='NO '),
#  Row(user_id_str='1245377257', whether_active='NO '),
#  Row(user_id_str='2497727850', whether_active='NO '),
#  Row(user_id_str='2242214617', whether_active='NO '),
#  Row(user_id_str='34282723', whether_active='NO '),
#  Row(user_id_str='2274181766', whether_active='NO '),
#  Row(user_id_str='2987648555', whether_active='NO '),
#  Row(user_id_str='35541189', whether_active='NO '),
#  Row(user_id_str='3295303734', whether_active='NO '),
#  Row(user_id_str='524732951', whether_active='NO '),
#  Row(user_id_str='79436911', whether_active='NO '),
#  Row(user_id_str='246987245', whether_active='NO '),
#  Row(user_id_str='757034374902743040', whether_active='NO '),
#  Row(user_id_str='2354303918', whether_active='NO '),
#  Row(user_id_str='22477252', whether_active='NO '),
#  Row(user_id_str='33829621', whether_active='NO '),
#  Row(user_id_str='481573383', whether_active='NO '),
#  Row(user_id_str='21850842', whether_active='NO '),
#  Row(user_id_str='785917438189670400', whether_active='NO '),
#  Row(user_id_str='101782427', whether_active='NO '),
#  Row(user_id_str='1437440348', whether_active='NO '),
#  Row(user_id_str='706169419718733824', whether_active='NO '),
#  Row(user_id_str='6177832', whether_active='NO '),
#  Row(user_id_str='120068456', whether_active='NO '),
#  Row(user_id_str='429016990', whether_active='NO '),
#  Row(user_id_str='20070088', whether_active='NO '),
#  Row(user_id_str='737213190681989121', whether_active='NO '),
#  Row(user_id_str='79260733', whether_active='NO '),
#  Row(user_id_str='18821935', whether_active='NO '),
#  Row(user_id_str='14934017', whether_active='NO '),
#  Row(user_id_str='1658664860', whether_active='NO '),
#  Row(user_id_str='704345455342313472', whether_active='NO '),
#  Row(user_id_str='499464698', whether_active='NO '),
#  Row(user_id_str='66370007', whether_active='NO '),
#  Row(user_id_str='83318092', whether_active='NO '),
#  Row(user_id_str='2755420775', whether_active='NO '),
#  Row(user_id_str='147572461', whether_active='NO '),
#  Row(user_id_str='19412382', whether_active='NO '),
#  Row(user_id_str='749383153937244164', whether_active='YES '),
#  Row(user_id_str='2259222409', whether_active='NO '),
#  Row(user_id_str='41701156', whether_active='NO '),
#  Row(user_id_str='3447333252', whether_active='NO '),
#  Row(user_id_str='724529047254917120', whether_active='NO '),
#  Row(user_id_str='1640461520', whether_active='NO '),
#  Row(user_id_str='154600632', whether_active='NO '),
#  Row(user_id_str='89850915', whether_active='NO '),
#  Row(user_id_str='64897527', whether_active='NO '),
#  Row(user_id_str='2669215596', whether_active='NO '),
#  Row(user_id_str='30260663', whether_active='NO '),
#  Row(user_id_str='522477612', whether_active='NO '),
#  Row(user_id_str='2865211326', whether_active='NO '),
#  Row(user_id_str='320756388', whether_active='NO '),
#  Row(user_id_str='396549156', whether_active='NO '),
#  Row(user_id_str='19236015', whether_active='NO '),
#  Row(user_id_str='76912915', whether_active='NO '),
#  Row(user_id_str='203874607', whether_active='NO '),
#  Row(user_id_str='2900142090', whether_active='NO '),
#  Row(user_id_str='19857548', whether_active='NO '),
#  Row(user_id_str='733398318353514496', whether_active='NO '),
#  Row(user_id_str='54941507', whether_active='NO '),
#  Row(user_id_str='194944968', whether_active='NO '),
#  Row(user_id_str='15605226', whether_active='NO '),
#  Row(user_id_str='140830709', whether_active='NO '),
#  Row(user_id_str='1552913352', whether_active='NO '),
#  Row(user_id_str='289396177', whether_active='NO '),
#  Row(user_id_str='21689397', whether_active='NO '),
#  Row(user_id_str='2984476775', whether_active='NO '),
#  Row(user_id_str='793853432138432512', whether_active='NO '),
#  Row(user_id_str='297504225', whether_active='NO '),
#  Row(user_id_str='485223335', whether_active='NO '),
#  Row(user_id_str='458070658', whether_active='NO '),
#  Row(user_id_str='4351459753', whether_active='NO '),
#  Row(user_id_str='50622864', whether_active='NO '),
#  Row(user_id_str='374212382', whether_active='NO '),
#  Row(user_id_str='48198318', whether_active='NO '),
#  Row(user_id_str='155180349', whether_active='NO '),
#  Row(user_id_str='261894160', whether_active='NO '),
#  Row(user_id_str='40847171', whether_active='NO '),
#  Row(user_id_str='885649502', whether_active='NO '),
#  Row(user_id_str='20620547', whether_active='NO '),
#  Row(user_id_str='2824549028', whether_active='NO '),
#  Row(user_id_str='459694718', whether_active='NO '),
#  Row(user_id_str='2414858826', whether_active='NO '),
#  Row(user_id_str='48569961', whether_active='NO '),
#  Row(user_id_str='36714114', whether_active='NO '),
#  Row(user_id_str='2960180055', whether_active='NO '),
#  Row(user_id_str='14156531', whether_active='NO '),
#  Row(user_id_str='153994363', whether_active='NO '),
#  Row(user_id_str='2995578334', whether_active='NO '),
#  Row(user_id_str='16630250', whether_active='NO '),
#  Row(user_id_str='409166295', whether_active='NO '),
#  Row(user_id_str='60760606', whether_active='NO '),
#  Row(user_id_str='1561239990', whether_active='NO '),
#  Row(user_id_str='227640177', whether_active='NO '),
#  Row(user_id_str='744083353431908352', whether_active='NO '),
#  Row(user_id_str='13220972', whether_active='NO '),
#  Row(user_id_str='1017546403', whether_active='NO '),
#  Row(user_id_str='1056873374', whether_active='NO '),
#  Row(user_id_str='1532349217', whether_active='NO '),
#  Row(user_id_str='2460952989', whether_active='NO '),
#  Row(user_id_str='3329627669', whether_active='NO '),
#  Row(user_id_str='3258741314', whether_active='NO '),
#  Row(user_id_str='1708132520', whether_active='NO '),
#  Row(user_id_str='145552068', whether_active='NO '),
#  Row(user_id_str='1694032592', whether_active='NO '),
#  Row(user_id_str='126296982', whether_active='NO '),
#  Row(user_id_str='752434454', whether_active='NO '),
#  Row(user_id_str='97015006', whether_active='NO '),
#  Row(user_id_str='493514962', whether_active='NO '),
#  Row(user_id_str='3188314726', whether_active='NO '),
#  Row(user_id_str='16999368', whether_active='NO '),
#  Row(user_id_str='80354812', whether_active='NO '),
#  Row(user_id_str='22195874', whether_active='NO '),
#  Row(user_id_str='463819805', whether_active='NO '),
#  Row(user_id_str='182114612', whether_active='NO '),
#  Row(user_id_str='45750321', whether_active='NO '),
#  Row(user_id_str='793877800289574912', whether_active='NO '),
#  Row(user_id_str='239057382', whether_active='NO '),
#  Row(user_id_str='281620069', whether_active='NO '),
#  Row(user_id_str='41451604', whether_active='NO '),
#  Row(user_id_str='21112079', whether_active='NO '),
#  Row(user_id_str='234004339', whether_active='NO '),
#  Row(user_id_str='3234250197', whether_active='NO '),
#  Row(user_id_str='156171571', whether_active='NO '),
#  Row(user_id_str='440069397', whether_active='NO '),
#  Row(user_id_str='134019610', whether_active='NO '),
#  Row(user_id_str='3195003018', whether_active='NO '),
#  Row(user_id_str='768214341246078976', whether_active='NO '),
#  Row(user_id_str='1307262936', whether_active='NO '),
#  Row(user_id_str='1860643051', whether_active='NO '),
#  Row(user_id_str='1955591882', whether_active='NO '),
#  Row(user_id_str='724573190', whether_active='NO '),
#  Row(user_id_str='130496112', whether_active='NO '),
#  Row(user_id_str='2980928403', whether_active='NO '),
#  Row(user_id_str='48097506', whether_active='NO '),
#  Row(user_id_str='762683882940534784', whether_active='NO '),
#  Row(user_id_str='231052516', whether_active='NO '),
#  Row(user_id_str='101599701', whether_active='NO '),
#  Row(user_id_str='112354863', whether_active='NO '),
#  Row(user_id_str='2467103148', whether_active='YES '),
#  Row(user_id_str='73984919', whether_active='NO '),
#  Row(user_id_str='3378924153', whether_active='NO '),
#  Row(user_id_str='186287415', whether_active='NO '),
#  Row(user_id_str='230626212', whether_active='NO '),
#  Row(user_id_str='30981617', whether_active='NO '),
#  Row(user_id_str='2450096531', whether_active='NO '),
#  Row(user_id_str='96982320', whether_active='NO '),
#  Row(user_id_str='36136637', whether_active='NO '),
#  Row(user_id_str='2980059869', whether_active='NO '),
#  Row(user_id_str='489094745', whether_active='NO '),
#  Row(user_id_str='2404991192', whether_active='NO '),
#  Row(user_id_str='16223638', whether_active='NO '),
#  Row(user_id_str='16388482', whether_active='NO '),
#  Row(user_id_str='4387461', whether_active='NO '),
#  Row(user_id_str='48938077', whether_active='NO '),
#  Row(user_id_str='723243194', whether_active='NO '),
#  Row(user_id_str='161449578', whether_active='NO '),
#  Row(user_id_str='143616096', whether_active='NO '),
#  Row(user_id_str='860548147', whether_active='NO '),
#  Row(user_id_str='44578594', whether_active='NO '),
#  Row(user_id_str='2790889266', whether_active='NO '),
#  Row(user_id_str='18596959', whether_active='NO '),
#  Row(user_id_str='2151837433', whether_active='NO '),
#  Row(user_id_str='43205023', whether_active='NO '),
#  Row(user_id_str='223570235', whether_active='NO '),
#  Row(user_id_str='524390443', whether_active='NO '),
#  Row(user_id_str='79725820', whether_active='NO '),
#  Row(user_id_str='33490437', whether_active='NO '),
#  Row(user_id_str='16049859', whether_active='NO '),
#  Row(user_id_str='479445356', whether_active='NO '),
#  Row(user_id_str='32131007', whether_active='NO '),
#  Row(user_id_str='3091359827', whether_active='NO '),
#  Row(user_id_str='225372484', whether_active='NO '),
#  Row(user_id_str='23695124', whether_active='NO '),
#  Row(user_id_str='30112164', whether_active='NO '),
#  Row(user_id_str='283512386', whether_active='NO '),
#  Row(user_id_str='40078503', whether_active='NO '),
#  Row(user_id_str='80040576', whether_active='NO '),
#  Row(user_id_str='196651500', whether_active='NO '),
#  Row(user_id_str='20158291', whether_active='NO '),
#  Row(user_id_str='2213419554', whether_active='NO '),
#  Row(user_id_str='127919462', whether_active='NO '),
#  Row(user_id_str='334116390', whether_active='NO '),
#  Row(user_id_str='729424684631130112', whether_active='NO '),
#  Row(user_id_str='166720784', whether_active='NO '),
#  Row(user_id_str='770726787466878976', whether_active='NO '),
#  Row(user_id_str='36278363', whether_active='NO '),
#  Row(user_id_str='2395255403', whether_active='NO '),
#  Row(user_id_str='331481523', whether_active='NO '),
#  Row(user_id_str='541238494', whether_active='NO '),
#  Row(user_id_str='1180539758', whether_active='NO '),
#  Row(user_id_str='287128801', whether_active='NO '),
#  Row(user_id_str='619427787', whether_active='YES '),
#  Row(user_id_str='761671164', whether_active='NO '),
#  Row(user_id_str='44645600', whether_active='NO '),
#  Row(user_id_str='994686457', whether_active='NO '),
#  Row(user_id_str='2353242859', whether_active='NO '),
#  Row(user_id_str='42853357', whether_active='NO '),
#  Row(user_id_str='149431832', whether_active='NO '),
#  Row(user_id_str='20045431', whether_active='NO '),
#  Row(user_id_str='78126698', whether_active='NO '),
#  Row(user_id_str='3082851141', whether_active='NO '),
#  Row(user_id_str='41917868', whether_active='NO '),
#  Row(user_id_str='374438999', whether_active='NO '),
#  Row(user_id_str='86668987', whether_active='NO '),
#  Row(user_id_str='329304994', whether_active='NO '),
#  Row(user_id_str='14511067', whether_active='NO '),
#  Row(user_id_str='4028697493', whether_active='NO '),
#  Row(user_id_str='885336408', whether_active='YES '),
#  Row(user_id_str='789767226249412608', whether_active='NO '),
#  Row(user_id_str='3346971111', whether_active='NO '),
#  Row(user_id_str='953901134', whether_active='NO '),
#  Row(user_id_str='1923986118', whether_active='NO '),
#  Row(user_id_str='248361725', whether_active='NO '),
#  Row(user_id_str='31343671', whether_active='NO '),
#  Row(user_id_str='16669765', whether_active='NO '),
#  Row(user_id_str='4494066677', whether_active='NO '),
#  Row(user_id_str='467046076', whether_active='NO '),
#  Row(user_id_str='4827082615', whether_active='NO '),
#  Row(user_id_str='219151894', whether_active='NO '),
#  Row(user_id_str='19815917', whether_active='NO '),
#  Row(user_id_str='19860569', whether_active='NO '),
#  Row(user_id_str='3973937112', whether_active='NO '),
#  Row(user_id_str='96779709', whether_active='NO '),
#  Row(user_id_str='470412760', whether_active='NO '),
#  Row(user_id_str='413233775', whether_active='NO '),
#  Row(user_id_str='164623724', whether_active='NO '),
#  Row(user_id_str='77827976', whether_active='NO '),
#  Row(user_id_str='70391352', whether_active='NO '),
#  Row(user_id_str='35323518', whether_active='NO '),
#  Row(user_id_str='245323551', whether_active='NO '),
#  Row(user_id_str='1146559795', whether_active='NO '),
#  Row(user_id_str='103140221', whether_active='NO '),
#  Row(user_id_str='4245183196', whether_active='NO '),
#  Row(user_id_str='3127117599', whether_active='NO '),
#  Row(user_id_str='2825383630', whether_active='NO '),
#  Row(user_id_str='1876523509', whether_active='NO '),
#  Row(user_id_str='39936715', whether_active='NO '),
#  Row(user_id_str='756663585707667457', whether_active='NO '),
#  Row(user_id_str='121513127', whether_active='NO '),
#  Row(user_id_str='778378277740122112', whether_active='NO '),
#  Row(user_id_str='18240730', whether_active='NO '),
#  Row(user_id_str='2200072755', whether_active='NO '),
#  Row(user_id_str='1859308328', whether_active='NO '),
#  Row(user_id_str='574136897', whether_active='NO '),
#  Row(user_id_str='746637564', whether_active='NO '),
#  Row(user_id_str='48826221', whether_active='NO '),
#  Row(user_id_str='32653092', whether_active='NO '),
#  Row(user_id_str='51267605', whether_active='NO '),
#  Row(user_id_str='220095890', whether_active='NO '),
#  Row(user_id_str='418264644', whether_active='NO '),
#  Row(user_id_str='71177611', whether_active='NO '),
#  Row(user_id_str='7765902', whether_active='NO '),
#  Row(user_id_str='1413124490', whether_active='NO '),
#  Row(user_id_str='611331270', whether_active='NO '),
#  Row(user_id_str='16169825', whether_active='NO '),
#  Row(user_id_str='22677368', whether_active='NO '),
#  Row(user_id_str='170591589', whether_active='NO '),
#  Row(user_id_str='1382631883', whether_active='NO '),
#  Row(user_id_str='47168113', whether_active='NO '),
#  Row(user_id_str='14715811', whether_active='NO '),
#  Row(user_id_str='112759229', whether_active='NO '),
#  Row(user_id_str='563818641', whether_active='NO '),
#  Row(user_id_str='2953950819', whether_active='NO '),
#  Row(user_id_str='40573844', whether_active='NO '),
#  Row(user_id_str='123063443', whether_active='NO '),
#  Row(user_id_str='16470450', whether_active='NO '),
#  Row(user_id_str='2488873374', whether_active='NO '),
#  Row(user_id_str='25113236', whether_active='NO '),
#  Row(user_id_str='2517601038', whether_active='NO '),
#  Row(user_id_str='767338929112567809', whether_active='NO '),
#  Row(user_id_str='101496743', whether_active='NO '),
#  Row(user_id_str='4666990218', whether_active='NO '),
#  Row(user_id_str='52669647', whether_active='NO '),
#  Row(user_id_str='600235351', whether_active='NO '),
#  Row(user_id_str='49263856', whether_active='YES '),
#  Row(user_id_str='283168534', whether_active='NO '),
#  Row(user_id_str='22078940', whether_active='NO '),
#  Row(user_id_str='45646219', whether_active='NO '),
#  Row(user_id_str='748311795731881984', whether_active='NO '),
#  Row(user_id_str='94114912', whether_active='NO '),
#  Row(user_id_str='3822557232', whether_active='NO '),
#  Row(user_id_str='1426939406', whether_active='YES '),
#  Row(user_id_str='117022992', whether_active='NO '),
#  Row(user_id_str='841448508', whether_active='NO '),
#  Row(user_id_str='321634113', whether_active='NO '),
#  Row(user_id_str='111567872', whether_active='NO '),
#  Row(user_id_str='230094546', whether_active='NO '),
#  Row(user_id_str='227910163', whether_active='NO '),
#  Row(user_id_str='77020260', whether_active='NO '),
#  Row(user_id_str='2413842998', whether_active='NO '),
#  Row(user_id_str='124711644', whether_active='NO '),
#  Row(user_id_str='359299986', whether_active='NO '),
#  Row(user_id_str='4361782161', whether_active='NO '),
#  Row(user_id_str='218100045', whether_active='NO '),
#  Row(user_id_str='444561240', whether_active='NO '),
#  Row(user_id_str='449556346', whether_active='NO '),
#  Row(user_id_str='141514699', whether_active='NO '),
#  Row(user_id_str='68398349', whether_active='YES '),
#  Row(user_id_str='13185272', whether_active='NO '),
#  Row(user_id_str='34403734', whether_active='NO '),
#  Row(user_id_str='1977690018', whether_active='NO '),
#  Row(user_id_str='72701241', whether_active='NO '),
#  Row(user_id_str='98873458', whether_active='NO '),
#  Row(user_id_str='40251516', whether_active='NO '),
#  Row(user_id_str='46228767', whether_active='YES '),
#  Row(user_id_str='2303638746', whether_active='NO '),
#  Row(user_id_str='146850968', whether_active='NO '),
#  Row(user_id_str='7287622', whether_active='NO '),
#  Row(user_id_str='2886602575', whether_active='NO '),
#  Row(user_id_str='40769391', whether_active='NO '),
#  Row(user_id_str='166096228', whether_active='NO '),
#  Row(user_id_str='158697330', whether_active='NO '),
#  Row(user_id_str='264218502', whether_active='NO '),
#  Row(user_id_str='2163213144', whether_active='NO '),
#  Row(user_id_str='28417220', whether_active='NO '),
#  Row(user_id_str='3318597149', whether_active='NO '),
#  Row(user_id_str='49401720', whether_active='NO '),
#  Row(user_id_str='1684636556', whether_active='NO '),
#  Row(user_id_str='109469032', whether_active='NO '),
#  Row(user_id_str='1328586871', whether_active='NO '),
#  Row(user_id_str='216030405', whether_active='NO '),
#  Row(user_id_str='209180682', whether_active='NO '),
#  Row(user_id_str='481567669', whether_active='NO '),
#  Row(user_id_str='2774375013', whether_active='NO '),
#  Row(user_id_str='339825758', whether_active='NO '),
#  Row(user_id_str='273988875', whether_active='NO '),
#  Row(user_id_str='331483931', whether_active='NO '),
#  Row(user_id_str='6927562', whether_active='NO '),
#  Row(user_id_str='155014004', whether_active='NO '),
#  Row(user_id_str='180726357', whether_active='NO '),
#  Row(user_id_str='35857831', whether_active='NO '),
#  Row(user_id_str='88541237', whether_active='NO '),
#  Row(user_id_str='2586648276', whether_active='NO '),
#  Row(user_id_str='113181276', whether_active='NO '),
#  Row(user_id_str='20479369', whether_active='NO '),
#  Row(user_id_str='6456692', whether_active='NO '),
#  Row(user_id_str='2197473794', whether_active='NO '),
#  Row(user_id_str='388545701', whether_active='NO '),
#  Row(user_id_str='87287475', whether_active='NO '),
#  Row(user_id_str='15212202', whether_active='NO '),
#  Row(user_id_str='1497020376', whether_active='NO '),
#  Row(user_id_str='21420819', whether_active='NO '),
#  Row(user_id_str='394339719', whether_active='NO '),
#  Row(user_id_str='347780670', whether_active='NO '),
#  Row(user_id_str='412218454', whether_active='NO '),
#  Row(user_id_str='151471706', whether_active='NO '),
#  Row(user_id_str='444045584', whether_active='NO '),
#  Row(user_id_str='3241686193', whether_active='NO '),
#  Row(user_id_str='307071884', whether_active='NO '),
#  Row(user_id_str='164729685', whether_active='NO '),
#  Row(user_id_str='211314838', whether_active='NO '),
#  Row(user_id_str='4252076728', whether_active='NO '),
#  Row(user_id_str='14286542', whether_active='NO '),
#  Row(user_id_str='21671483', whether_active='NO '),
#  Row(user_id_str='3388544465', whether_active='NO '),
#  Row(user_id_str='23845398', whether_active='NO '),
#  Row(user_id_str='2897133662', whether_active='NO '),
#  Row(user_id_str='300931329', whether_active='NO '),
#  Row(user_id_str='28450322', whether_active='NO '),
#  Row(user_id_str='207016716', whether_active='NO '),
#  Row(user_id_str='18267432', whether_active='NO '),
#  Row(user_id_str='41457911', whether_active='NO '),
#  Row(user_id_str='468476916', whether_active='NO '),
#  Row(user_id_str='8922082', whether_active='NO '),
#  Row(user_id_str='28291808', whether_active='NO '),
#  Row(user_id_str='617875930', whether_active='NO '),
#  Row(user_id_str='28070351', whether_active='NO '),
#  Row(user_id_str='14178066', whether_active='NO '),
#  Row(user_id_str='772890069938081793', whether_active='NO '),
#  Row(user_id_str='637224461', whether_active='NO '),
#  Row(user_id_str='1056165000', whether_active='NO '),
#  Row(user_id_str='470553237', whether_active='NO '),
#  Row(user_id_str='2573219121', whether_active='NO '),
#  Row(user_id_str='49750455', whether_active='NO '),
#  Row(user_id_str='391010001', whether_active='NO '),
#  Row(user_id_str='1299813354', whether_active='NO '),
#  Row(user_id_str='615138587', whether_active='NO '),
#  Row(user_id_str='1259743393', whether_active='NO '),
#  Row(user_id_str='619522261', whether_active='NO '),
#  Row(user_id_str='21875869', whether_active='NO '),
#  Row(user_id_str='44737051', whether_active='NO '),
#  Row(user_id_str='4708108637', whether_active='NO '),
#  Row(user_id_str='2998233178', whether_active='NO '),
#  Row(user_id_str='36746331', whether_active='NO '),
#  Row(user_id_str='2927219833', whether_active='NO '),
#  Row(user_id_str='12144232', whether_active='NO '),
#  Row(user_id_str='800813617', whether_active='NO '),
#  Row(user_id_str='3304637221', whether_active='NO '),
#  Row(user_id_str='132345637', whether_active='NO '),
#  Row(user_id_str='21287437', whether_active='NO '),
#  Row(user_id_str='101879535', whether_active='NO '),
#  Row(user_id_str='2780953026', whether_active='NO '),
#  Row(user_id_str='3758506395', whether_active='NO '),
#  Row(user_id_str='697098786942885888', whether_active='NO '),
#  Row(user_id_str='2340821', whether_active='NO '),
#  Row(user_id_str='603712296', whether_active='NO '),
#  Row(user_id_str='57340573', whether_active='NO '),
#  Row(user_id_str='781965044892524544', whether_active='NO '),
#  Row(user_id_str='391582041', whether_active='NO '),
#  Row(user_id_str='2735624285', whether_active='NO '),
#  Row(user_id_str='79378269', whether_active='NO '),
#  Row(user_id_str='1107690745', whether_active='NO '),
#  Row(user_id_str='270396051', whether_active='NO '),
#  Row(user_id_str='1015987736', whether_active='NO '),
#  Row(user_id_str='1433596662', whether_active='NO '),
#  Row(user_id_str='901169144', whether_active='NO '),
#  Row(user_id_str='336941297', whether_active='NO '),
#  Row(user_id_str='90924839', whether_active='NO '),
#  Row(user_id_str='333867039', whether_active='NO '),
#  Row(user_id_str='1587800580', whether_active='NO '),
#  Row(user_id_str='15374193', whether_active='NO '),
#  Row(user_id_str='898250437', whether_active='NO '),
#  Row(user_id_str='120838314', whether_active='NO '),
#  Row(user_id_str='19919515', whether_active='YES '),
#  Row(user_id_str='1282440788', whether_active='NO '),
#  Row(user_id_str='2231539655', whether_active='NO '),
#  Row(user_id_str='153682905', whether_active='NO '),
#  Row(user_id_str='395496665', whether_active='NO '),
#  Row(user_id_str='235546963', whether_active='NO '),
#  Row(user_id_str='2856962985', whether_active='NO '),
#  Row(user_id_str='236599759', whether_active='NO '),
#  Row(user_id_str='792816445637926912', whether_active='NO '),
#  Row(user_id_str='97359917', whether_active='NO '),
#  Row(user_id_str='264910184', whether_active='NO '),
#  Row(user_id_str='85868833', whether_active='NO '),
#  Row(user_id_str='16059827', whether_active='NO '),
#  Row(user_id_str='107422115', whether_active='NO '),
#  Row(user_id_str='322230922', whether_active='NO '),
#  Row(user_id_str='110614239', whether_active='NO '),
#  Row(user_id_str='118712723', whether_active='NO '),
#  Row(user_id_str='43370459', whether_active='NO '),
#  Row(user_id_str='86866410', whether_active='NO '),
#  Row(user_id_str='182811243', whether_active='NO '),
#  Row(user_id_str='350308945', whether_active='NO '),
#  Row(user_id_str='872616324', whether_active='NO '),
#  Row(user_id_str='218176653', whether_active='NO '),
#  Row(user_id_str='751094263870545924', whether_active='NO '),
#  Row(user_id_str='90510002', whether_active='NO '),
#  Row(user_id_str='467554781', whether_active='NO '),
#  Row(user_id_str='160326340', whether_active='NO '),
#  Row(user_id_str='470228513', whether_active='NO '),
#  Row(user_id_str='51824516', whether_active='NO '),
#  Row(user_id_str='17030728', whether_active='NO '),
#  Row(user_id_str='367853187', whether_active='NO '),
#  Row(user_id_str='953947501', whether_active='YES '),
#  Row(user_id_str='23756473', whether_active='NO '),
#  Row(user_id_str='20066293', whether_active='NO '),
#  Row(user_id_str='2572375764', whether_active='NO '),
#  Row(user_id_str='189975748', whether_active='NO '),
#  Row(user_id_str='72342053', whether_active='NO '),
#  Row(user_id_str='55160211', whether_active='NO '),
#  Row(user_id_str='84390105', whether_active='NO '),
#  Row(user_id_str='2189027816', whether_active='YES '),
#  Row(user_id_str='173736457', whether_active='NO '),
#  Row(user_id_str='2960386147', whether_active='NO '),
#  Row(user_id_str='726316472947986432', whether_active='NO '),
#  Row(user_id_str='230429587', whether_active='NO '),
#  Row(user_id_str='1539218622', whether_active='NO '),
#  Row(user_id_str='28397661', whether_active='NO '),
#  Row(user_id_str='727790783437246465', whether_active='NO '),
#  Row(user_id_str='67290915', whether_active='NO '),
#  Row(user_id_str='2854616179', whether_active='NO '),
#  Row(user_id_str='17641725', whether_active='NO '),
#  Row(user_id_str='2974841467', whether_active='NO '),
#  Row(user_id_str='2366888623', whether_active='YES '),
#  Row(user_id_str='2851697636', whether_active='NO '),
#  Row(user_id_str='746674676492013568', whether_active='NO '),
#  Row(user_id_str='569410380', whether_active='NO '),
#  Row(user_id_str='3198506329', whether_active='NO '),
#  Row(user_id_str='794216898644869120', whether_active='NO '),
#  Row(user_id_str='2535272502', whether_active='NO '),
#  Row(user_id_str='471697777', whether_active='NO '),
#  Row(user_id_str='173297485', whether_active='NO '),
#  Row(user_id_str='2488775060', whether_active='NO '),
#  Row(user_id_str='185954790', whether_active='NO '),
#  Row(user_id_str='329538941', whether_active='NO '),
#  Row(user_id_str='1513009609', whether_active='NO '),
#  Row(user_id_str='543571642', whether_active='YES '),
#  Row(user_id_str='62304497', whether_active='NO '),
#  Row(user_id_str='40936936', whether_active='NO '),
#  Row(user_id_str='780540098', whether_active='NO '),
#  Row(user_id_str='2171653297', whether_active='NO '),
#  Row(user_id_str='3679987464', whether_active='NO '),
#  Row(user_id_str='3191823195', whether_active='NO '),
#  Row(user_id_str='16611081', whether_active='NO '),
#  Row(user_id_str='86762070', whether_active='YES '),
#  Row(user_id_str='588300950', whether_active='NO '),
#  Row(user_id_str='26787826', whether_active='YES '),
#  Row(user_id_str='18245601', whether_active='NO '),
#  Row(user_id_str='170352544', whether_active='NO '),
#  Row(user_id_str='71190470', whether_active='NO '),
#  Row(user_id_str='777593585629814784', whether_active='NO '),
#  Row(user_id_str='73097498', whether_active='YES '),
#  Row(user_id_str='3322188248', whether_active='YES '),
#  Row(user_id_str='31453996', whether_active='NO '),
#  Row(user_id_str='64988324', whether_active='NO '),
#  Row(user_id_str='778629076940500992', whether_active='NO '),
#  Row(user_id_str='111109304', whether_active='NO '),
#  Row(user_id_str='268256709', whether_active='NO '),
#  Row(user_id_str='47039868', whether_active='NO '),
#  Row(user_id_str='62059958', whether_active='NO '),
#  Row(user_id_str='1440700358', whether_active='NO '),
#  Row(user_id_str='713949712194215938', whether_active='NO '),
#  Row(user_id_str='62589198', whether_active='NO '),
#  Row(user_id_str='1382868224', whether_active='NO '),
#  Row(user_id_str='113948965', whether_active='NO '),
#  Row(user_id_str='55197678', whether_active='NO '),
#  Row(user_id_str='1193371062', whether_active='NO '),
#  Row(user_id_str='393362049', whether_active='NO '),
#  Row(user_id_str='64041474', whether_active='YES '),
#  Row(user_id_str='95240527', whether_active='NO '),
#  Row(user_id_str='70380059', whether_active='NO '),
#  Row(user_id_str='1636351038', whether_active='NO '),
#  Row(user_id_str='129126829', whether_active='NO '),
#  Row(user_id_str='29698415', whether_active='NO '),
#  Row(user_id_str='142201059', whether_active='NO '),
#  Row(user_id_str='715130976935026688', whether_active='NO '),
#  Row(user_id_str='195448833', whether_active='NO '),
#  Row(user_id_str='173123534', whether_active='NO '),
#  Row(user_id_str='61606664', whether_active='YES '),
#  Row(user_id_str='2482688934', whether_active='NO '),
#  Row(user_id_str='17625406', whether_active='NO '),
#  Row(user_id_str='19265076', whether_active='NO '),
#  Row(user_id_str='950549930', whether_active='NO '),
#  Row(user_id_str='2912840879', whether_active='NO '),
#  Row(user_id_str='1017832603', whether_active='NO '),
#  Row(user_id_str='2362291682', whether_active='NO '),
#  Row(user_id_str='2986338112', whether_active='NO '),
#  Row(user_id_str='160675684', whether_active='NO '),
#  Row(user_id_str='301381979', whether_active='YES '),
#  Row(user_id_str='27969435', whether_active='NO '),
#  Row(user_id_str='19436808', whether_active='NO '),
#  Row(user_id_str='1600931', whether_active='NO '),
#  Row(user_id_str='33553251', whether_active='NO '),
#  Row(user_id_str='1483276698', whether_active='NO '),
#  Row(user_id_str='81979954', whether_active='NO '),
#  Row(user_id_str='1140305274', whether_active='NO '),
#  Row(user_id_str='922660980', whether_active='NO '),
#  Row(user_id_str='3336074537', whether_active='NO '),
#  Row(user_id_str='19756713', whether_active='NO '),
#  Row(user_id_str='267381861', whether_active='YES '),
#  Row(user_id_str='2254085371', whether_active='NO '),
#  Row(user_id_str='2197970570', whether_active='NO '),
#  Row(user_id_str='20269328', whether_active='NO '),
#  Row(user_id_str='870597439', whether_active='NO '),
#  Row(user_id_str='1584883788', whether_active='NO '),
#  Row(user_id_str='1024124958', whether_active='NO '),
#  Row(user_id_str='17493016', whether_active='NO '),
#  Row(user_id_str='29980396', whether_active='NO '),
#  Row(user_id_str='721377902252683264', whether_active='NO '),
#  Row(user_id_str='422753927', whether_active='NO '),
#  Row(user_id_str='15250896', whether_active='NO '),
#  Row(user_id_str='54507491', whether_active='NO '),
#  Row(user_id_str='39509314', whether_active='NO '),
#  Row(user_id_str='820494696', whether_active='NO '),
#  Row(user_id_str='162914061', whether_active='NO '),
#  Row(user_id_str='3646971856', whether_active='NO '),
#  Row(user_id_str='2876804250', whether_active='NO '),
#  Row(user_id_str='90481271', whether_active='NO '),
#  Row(user_id_str='74426342', whether_active='NO '),
#  Row(user_id_str='61323080', whether_active='NO '),
#  Row(user_id_str='36175296', whether_active='NO '),
#  Row(user_id_str='3057228958', whether_active='NO '),
#  Row(user_id_str='455290024', whether_active='NO '),
#  Row(user_id_str='15309467', whether_active='NO '),
#  Row(user_id_str='133372179', whether_active='NO '),
#  Row(user_id_str='158901096', whether_active='NO '),
#  Row(user_id_str='2875793995', whether_active='NO '),
#  Row(user_id_str='1169020747', whether_active='NO '),
#  Row(user_id_str='23340607', whether_active='NO '),
#  Row(user_id_str='19451813', whether_active='NO '),
#  Row(user_id_str='2369485963', whether_active='NO '),
#  Row(user_id_str='2994564113', whether_active='NO '),
#  Row(user_id_str='529541551', whether_active='NO '),
#  Row(user_id_str='423716129', whether_active='NO '),
#  Row(user_id_str='379378914', whether_active='NO '),
#  Row(user_id_str='2523514141', whether_active='NO '),
#  Row(user_id_str='21024374', whether_active='NO '),
#  Row(user_id_str='98863587', whether_active='NO '),
#  Row(user_id_str='1171182668', whether_active='NO '),
#  Row(user_id_str='20561973', whether_active='NO '),
#  Row(user_id_str='384695518', whether_active='NO '),
#  Row(user_id_str='1708460220', whether_active='NO '),
#  Row(user_id_str='4482616212', whether_active='NO '),
#  Row(user_id_str='20501629', whether_active='NO '),
#  Row(user_id_str='14326901', whether_active='NO '),
#  Row(user_id_str='45261250', whether_active='NO '),
#  Row(user_id_str='48893323', whether_active='NO '),
#  Row(user_id_str='928763503', whether_active='NO '),
#  Row(user_id_str='211419571', whether_active='NO '),
#  Row(user_id_str='535015099', whether_active='NO '),
#  Row(user_id_str='125675649', whether_active='YES '),
#  Row(user_id_str='274670671', whether_active='NO '),
#  Row(user_id_str='15154216', whether_active='NO '),
#  Row(user_id_str='842317388', whether_active='NO '),
#  Row(user_id_str='367676040', whether_active='NO '),
#  ...]

# %%
yes = experiment_user.filter(experiment_user.whether_active.contains('YES')).count()
no = experiment_user.filter(experiment_user.whether_active.contains('NO')).count()

# %%
percentage_of_active_users = (yes/(yes+no))*100

# %%
percentage_of_active_users
# Out:
# 2.42

# %%
ans2 = sqlContext.sql("Select t1.user_id_str,t2.user_screen_name from table_1 as t1 join table_2 as t2 on t1.user_id_str = t2.user_id_str")

# %%
ans2.show(5)
# Out:
# +-----------+----------------+
# |user_id_str|user_screen_name|
# +-----------+----------------+
# |   18435372|          medtek|
# | 1387267123|      TheMimiZee|
# |  267381861|      SparklyPen|
# |  885336408|    J_cooper1990|
# |  213060183|         ke4ole1|
# +-----------+----------------+
# only showing top 5 rows

# %%
sqlContext.registerDataFrameAsTable(data, "tab1")
sqlContext.registerDataFrameAsTable(daily_active_users, "tab2")
sqlContext.registerDataFrameAsTable(experiment_user,"tab3")

# %%
ans_1 = sqlContext.sql("Select t1.*  from tab1 as t1 inner join tab2 as t2 on t1.user_id_str = t2.user_id_str inner join tab3 as t3 on t1.user_id_str = t3.user_id_str")

# %%
x = ans_1.collect()

# %%
import pandas as pd

# %%
columns = [entry for entry in data.columns]

# %%
data_final = pd.DataFrame(x,columns = columns)

# %%
data_final.to_csv('Amazon_new.csv')
